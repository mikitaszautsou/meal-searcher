# %%
import json

# Load the JSON data from data.json
with open('FoodData_Central_sr_legacy_food_json_2021-10-28.json') as f:
    data = json.load(f)



# exclude food with name in EXCLUDED_FOOD_NAME or contains part of name in EXCLUDED_FOOD_NAME_PART
data['SRLegacyFoods'] = [food for food in data['SRLegacyFoods'] if food['description'] not in EXCLUDED_FOOD_NAME and all(part not in food['description'] for part in EXCLUDED_FOOD_NAME_PART)]

# %%
original_food = data['SRLegacyFoods']

# %%
# # select 10% of the data randomly but without changing the original data
import random
random.seed(4)
random.shuffle(original_food)
data['SRLegacyFoods'] = original_food[:int(len(original_food)*0.70)]

# %%
data['SRLegacyFoods'][0]['foodNutrients']
# Out:
# [{'type': 'FoodNutrient',
#   'id': 1477440,
#   'nutrient': {'id': 1057,
#    'number': '262',
#    'name': 'Caffeine',
#    'rank': 18300,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477441,
#   'nutrient': {'id': 1058,
#    'number': '263',
#    'name': 'Theobromine',
#    'rank': 18400,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477442,
#   'nutrient': {'id': 1123,
#    'number': '338',
#    'name': 'Lutein + zeaxanthin',
#    'rank': 7560,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477443,
#   'nutrient': {'id': 1109,
#    'number': '323',
#    'name': 'Vitamin E (alpha-tocopherol)',
#    'rank': 7905,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'O',
#    'description': 'Other procedure used from imputing',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 1.73},
#  {'type': 'FoodNutrient',
#   'id': 1477444,
#   'nutrient': {'id': 1186,
#    'number': '431',
#    'name': 'Folic acid',
#    'rank': 7000,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477445,
#   'nutrient': {'id': 1007,
#    'number': '207',
#    'name': 'Ash',
#    'rank': 1000,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'O',
#    'description': 'Other procedure used from imputing',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 4.0},
#  {'type': 'FoodNutrient',
#   'id': 1477446,
#   'nutrient': {'id': 1105,
#    'number': '319',
#    'name': 'Retinol',
#    'rank': 7430,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477447,
#   'nutrient': {'id': 1107,
#    'number': '321',
#    'name': 'Carotene, beta',
#    'rank': 7440,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477448,
#   'nutrient': {'id': 1108,
#    'number': '322',
#    'name': 'Carotene, alpha',
#    'rank': 7450,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477449,
#   'nutrient': {'id': 1120,
#    'number': '334',
#    'name': 'Cryptoxanthin, beta',
#    'rank': 7460,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477450,
#   'nutrient': {'id': 1122,
#    'number': '337',
#    'name': 'Lycopene',
#    'rank': 7530,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477451,
#   'nutrient': {'id': 1185,
#    'number': '430',
#    'name': 'Vitamin K (phylloquinone)',
#    'rank': 8800,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477452,
#   'nutrient': {'id': 1246,
#    'number': '578',
#    'name': 'Vitamin B-12, added',
#    'rank': 7340,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'NR',
#    'description': 'Nutrient that is based on other nutrient/s; value used directly, ex. Nut.#204 from Nut.#298',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 2.4},
#  {'type': 'FoodNutrient',
#   'id': 1477453,
#   'nutrient': {'id': 1110,
#    'number': '324',
#    'name': 'Vitamin D (D2 + D3), International Units',
#    'rank': 8650,
#    'unitName': 'IU'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477454,
#   'nutrient': {'id': 1004,
#    'number': '204',
#    'name': 'Total lipid (fat)',
#    'rank': 800,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 9.0},
#  {'type': 'FoodNutrient',
#   'id': 1477455,
#   'nutrient': {'id': 1005,
#    'number': '205',
#    'name': 'Carbohydrate, by difference',
#    'rank': 1110,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'NC',
#    'description': 'Calculated',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 8.0},
#  {'type': 'FoodNutrient',
#   'id': 1477456,
#   'nutrient': {'id': 1008,
#    'number': '208',
#    'name': 'Energy',
#    'rank': 300,
#    'unitName': 'kcal'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'NC',
#    'description': 'Calculated',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 197},
#  {'type': 'FoodNutrient',
#   'id': 1477457,
#   'nutrient': {'id': 1051,
#    'number': '255',
#    'name': 'Water',
#    'rank': 100,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 58.0},
#  {'type': 'FoodNutrient',
#   'id': 1477458,
#   'nutrient': {'id': 2000,
#    'number': '269',
#    'name': 'Sugars, total including NLEA',
#    'rank': 1510,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'LC',
#    'description': 'Label claim (back calculated from label by NDL staff; Calculated from label claim/serving (g or %RDI)',
#    'foodNutrientSource': {'id': 6,
#     'code': '8',
#     'description': 'Calculated from nutrient label by NDL'}},
#   'amount': 1.2},
#  {'type': 'FoodNutrient',
#   'id': 1477459,
#   'nutrient': {'id': 1087,
#    'number': '301',
#    'name': 'Calcium, Ca',
#    'rank': 5300,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 29.0},
#  {'type': 'FoodNutrient',
#   'id': 1477460,
#   'nutrient': {'id': 1092,
#    'number': '306',
#    'name': 'Potassium, K',
#    'rank': 5700,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 180},
#  {'type': 'FoodNutrient',
#   'id': 1477461,
#   'nutrient': {'id': 1095,
#    'number': '309',
#    'name': 'Zinc, Zn',
#    'rank': 5900,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 1.8},
#  {'type': 'FoodNutrient',
#   'id': 1477462,
#   'nutrient': {'id': 1259,
#    'number': '607',
#    'name': 'SFA 4:0',
#    'rank': 9800,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477463,
#   'nutrient': {'id': 1260,
#    'number': '608',
#    'name': 'SFA 6:0',
#    'rank': 9900,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477464,
#   'nutrient': {'id': 1262,
#    'number': '610',
#    'name': 'SFA 10:0',
#    'rank': 10100,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477465,
#   'nutrient': {'id': 1265,
#    'number': '613',
#    'name': 'SFA 16:0',
#    'rank': 10700,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.925},
#  {'type': 'FoodNutrient',
#   'id': 1477466,
#   'nutrient': {'id': 1266,
#    'number': '614',
#    'name': 'SFA 18:0',
#    'rank': 10900,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.369},
#  {'type': 'FoodNutrient',
#   'id': 1477467,
#   'nutrient': {'id': 1268,
#    'number': '617',
#    'name': 'MUFA 18:1',
#    'rank': 12100,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 2.19},
#  {'type': 'FoodNutrient',
#   'id': 1477468,
#   'nutrient': {'id': 1269,
#    'number': '618',
#    'name': 'PUFA 18:2',
#    'rank': 13100,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 4.15},
#  {'type': 'FoodNutrient',
#   'id': 1477469,
#   'nutrient': {'id': 1270,
#    'number': '619',
#    'name': 'PUFA 18:3',
#    'rank': 13900,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.52},
#  {'type': 'FoodNutrient',
#   'id': 1477470,
#   'nutrient': {'id': 1271,
#    'number': '620',
#    'name': 'PUFA 20:4',
#    'rank': 14700,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477471,
#   'nutrient': {'id': 1276,
#    'number': '627',
#    'name': 'PUFA 18:4',
#    'rank': 14250,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477472,
#   'nutrient': {'id': 1277,
#    'number': '628',
#    'name': 'MUFA 20:1',
#    'rank': 12400,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477473,
#   'nutrient': {'id': 1279,
#    'number': '630',
#    'name': 'MUFA 22:1',
#    'rank': 12500,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477474,
#   'nutrient': {'id': 1292,
#    'number': '645',
#    'name': 'Fatty acids, total monounsaturated',
#    'rank': 11400,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 2.19},
#  {'type': 'FoodNutrient',
#   'id': 1477475,
#   'nutrient': {'id': 1293,
#    'number': '646',
#    'name': 'Fatty acids, total polyunsaturated',
#    'rank': 12900,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 4.67},
#  {'type': 'FoodNutrient',
#   'id': 1477476,
#   'nutrient': {'id': 1190,
#    'number': '435',
#    'name': 'Folate, DFE',
#    'rank': 7200,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'NC',
#    'description': 'Calculated',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 78.0},
#  {'type': 'FoodNutrient',
#   'id': 1477477,
#   'nutrient': {'id': 1167,
#    'number': '406',
#    'name': 'Niacin',
#    'rank': 6600,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 10.0},
#  {'type': 'FoodNutrient',
#   'id': 1477478,
#   'nutrient': {'id': 1175,
#    'number': '415',
#    'name': 'Vitamin B-6',
#    'rank': 6800,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 1.2},
#  {'type': 'FoodNutrient',
#   'id': 1477479,
#   'nutrient': {'id': 1180,
#    'number': '421',
#    'name': 'Choline, total',
#    'rank': 7220,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'BFNN',
#    'description': 'Based on another form of the food or similar food; Concentration adjustment; Non-fat solids; Retention factors not used',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 73.1},
#  {'type': 'FoodNutrient',
#   'id': 1477480,
#   'nutrient': {'id': 1003,
#    'number': '203',
#    'name': 'Protein',
#    'rank': 600,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 21.0},
#  {'type': 'FoodNutrient',
#   'id': 1477481,
#   'nutrient': {'id': 1162,
#    'number': '401',
#    'name': 'Vitamin C, total ascorbic acid',
#    'rank': 6300,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477482,
#   'nutrient': {'id': 1165,
#    'number': '404',
#    'name': 'Thiamin',
#    'rank': 6400,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.9},
#  {'type': 'FoodNutrient',
#   'id': 1477483,
#   'nutrient': {'id': 1166,
#    'number': '405',
#    'name': 'Riboflavin',
#    'rank': 6500,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.6},
#  {'type': 'FoodNutrient',
#   'id': 1477484,
#   'nutrient': {'id': 1177,
#    'number': '417',
#    'name': 'Folate, total',
#    'rank': 6900,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 78.0},
#  {'type': 'FoodNutrient',
#   'id': 1477485,
#   'nutrient': {'id': 1178,
#    'number': '418',
#    'name': 'Vitamin B-12',
#    'rank': 7300,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 2.4},
#  {'type': 'FoodNutrient',
#   'id': 1477486,
#   'nutrient': {'id': 1106,
#    'number': '320',
#    'name': 'Vitamin A, RAE',
#    'rank': 7420,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477487,
#   'nutrient': {'id': 1018,
#    'number': '221',
#    'name': 'Alcohol, ethyl',
#    'rank': 18200,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477488,
#   'nutrient': {'id': 1062,
#    'number': '268',
#    'name': 'Energy',
#    'rank': 400,
#    'unitName': 'kJ'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'NC',
#    'description': 'Calculated',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 824},
#  {'type': 'FoodNutrient',
#   'id': 1477489,
#   'nutrient': {'id': 1079,
#    'number': '291',
#    'name': 'Fiber, total dietary',
#    'rank': 1200,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 4.6},
#  {'type': 'FoodNutrient',
#   'id': 1477490,
#   'nutrient': {'id': 1089,
#    'number': '303',
#    'name': 'Iron, Fe',
#    'rank': 5400,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 2.1},
#  {'type': 'FoodNutrient',
#   'id': 1477491,
#   'nutrient': {'id': 1090,
#    'number': '304',
#    'name': 'Magnesium, Mg',
#    'rank': 5500,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 18.0},
#  {'type': 'FoodNutrient',
#   'id': 1477492,
#   'nutrient': {'id': 1091,
#    'number': '305',
#    'name': 'Phosphorus, P',
#    'rank': 5600,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 344},
#  {'type': 'FoodNutrient',
#   'id': 1477493,
#   'nutrient': {'id': 1093,
#    'number': '307',
#    'name': 'Sodium, Na',
#    'rank': 5800,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 550},
#  {'type': 'FoodNutrient',
#   'id': 1477494,
#   'nutrient': {'id': 1098,
#    'number': '312',
#    'name': 'Copper, Cu',
#    'rank': 6000,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.706},
#  {'type': 'FoodNutrient',
#   'id': 1477495,
#   'nutrient': {'id': 1104,
#    'number': '318',
#    'name': 'Vitamin A, IU',
#    'rank': 7500,
#    'unitName': 'IU'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477496,
#   'nutrient': {'id': 1253,
#    'number': '601',
#    'name': 'Cholesterol',
#    'rank': 15700,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477497,
#   'nutrient': {'id': 1187,
#    'number': '432',
#    'name': 'Folate, food',
#    'rank': 7100,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 78.0},
#  {'type': 'FoodNutrient',
#   'id': 1477498,
#   'nutrient': {'id': 1258,
#    'number': '606',
#    'name': 'Fatty acids, total saturated',
#    'rank': 9700,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 1.42},
#  {'type': 'FoodNutrient',
#   'id': 1477499,
#   'nutrient': {'id': 1261,
#    'number': '609',
#    'name': 'SFA 8:0',
#    'rank': 10000,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477500,
#   'nutrient': {'id': 1263,
#    'number': '611',
#    'name': 'SFA 12:0',
#    'rank': 10300,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.087},
#  {'type': 'FoodNutrient',
#   'id': 1477501,
#   'nutrient': {'id': 1264,
#    'number': '612',
#    'name': 'SFA 14:0',
#    'rank': 10500,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.043},
#  {'type': 'FoodNutrient',
#   'id': 1477502,
#   'nutrient': {'id': 1272,
#    'number': '621',
#    'name': 'PUFA 22:6 n-3 (DHA)',
#    'rank': 15300,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477503,
#   'nutrient': {'id': 1275,
#    'number': '626',
#    'name': 'MUFA 16:1',
#    'rank': 11700,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477504,
#   'nutrient': {'id': 1278,
#    'number': '629',
#    'name': 'PUFA 2:5 n-3 (EPA)',
#    'rank': 15000,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477505,
#   'nutrient': {'id': 1280,
#    'number': '631',
#    'name': 'PUFA 22:5 n-3 (DPA)',
#    'rank': 15200,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'foodNutrientSource': {}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477506,
#   'nutrient': {'id': 1257,
#    'number': '605',
#    'name': 'Fatty acids, total trans',
#    'rank': 15400,
#    'unitName': 'g'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477507,
#   'nutrient': {'id': 1242,
#    'number': '573',
#    'name': 'Vitamin E, added',
#    'rank': 7920,
#    'unitName': 'mg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477508,
#   'nutrient': {'id': 1114,
#    'number': '328',
#    'name': 'Vitamin D (D2 + D3)',
#    'rank': 8700,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'Z',
#    'description': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)',
#    'foodNutrientSource': {'id': 5,
#     'code': '7',
#     'description': 'Assumed zero'}},
#   'amount': 0.0},
#  {'type': 'FoodNutrient',
#   'id': 1477509,
#   'nutrient': {'id': 1103,
#    'number': '317',
#    'name': 'Selenium, Se',
#    'rank': 6200,
#    'unitName': 'Âµg'},
#   'dataPoints': 0,
#   'foodNutrientDerivation': {'code': 'BFSN',
#    'description': 'Based on another form of the food or similar food; Concentration adjustment; Solids; Retention factors not used',
#    'foodNutrientSource': {'id': 2,
#     'code': '4',
#     'description': 'Calculated or imputed'}},
#   'amount': 0.8}]

# %%
EXCLUDED_FOOD_NAME = ['Corn oil', 'Lard','Gin', 'Rum', 'Pasta with tomato based sauce and poultry, home recipe']
EXCLUDED_FOOD_NAME_PART = [
    'Tortilla ',
    'Candy, ',
    'Dandelion ',
    ', eel',
    'Nutritional powder mix',
    ' chips',
    'Sun-dried ',
    'Yeast extract spread',
    ' Toddler ',
    'Coffee, ',
    'yolk only',
    ' carp',
    'Pizza ',
    'Pork skin rinds',
    ' canned,',
    ' sauce,',
    'Vegetable, dried',
    'Chitterlings',
    'Cookie, ',
    'Crackers, ',
    ' trout',
    'Kidney',
    'Spaghetti sauce',
    'Vegetable mixture',
    'Brains',
    'Caviar',
    'Fruit flavored drink',
    'Liver, beef',
    'Sloppy joe',
    'Rice cake',
    'Popcorn',
    'Nutrition bar',
    'Melba toast',
    'Chocolate beverage powder',
    ' sauce',
    'Vegetarian chili, made with meat substitute',
    'Topping from cheese pizza',
    'Chips',
    'Tea, iced, instant, black, unsweetened, dry',
    "O's",
    'rice crispy',
    "Cereal, K's, plain",
    'Cereal, oat bunches',
    'Cereal, plain puffs',
    ', mackerel',
    'MALT O MEAL',
    'Protein powder',
    'fortified',
    ' with honey',
    'Infant formula,',
    ' liver,',
    'Babyfood, ',
    'Spices, thyme, drie',
    'Parmesan',
    'shredded wheat',
    'Winter squash',
    'Rice crackers',
    'Spices, ',
    'Acerola',
    'Candies',
    ', canned',
    'malt-o-meal',
    ' oyster',
    'halibut',
    'CREAM OF WHEAT',
    'QUAKER, QUAKER',
    'Desserts',
    'protein',
    'cottonseed flour',
    'Frostings',
    'Mollusks',
    'Bacon ',
    'Fish oil, cod liver',
    ' cod,',
    'Corn flour',
    'Cookies',
    ' tea',
    'Oil, beluga',
    'Fish, salmon, chum, dried',
    'Fat, chicken',
    'pork skins',
    'Seeds, cottonseed meal',
    'Margarine',
    'Egg, yolk, dried',
    'Egg, white, dried',
    'industrial',
    'Oil, soybean lecithin',
    'Oil, hazelnut',
    'Oil, PAM cooking spray, original',
    'Oil, sunflower',
    'Fat, beef tallow',
    'Oil, whale, bowhead',
    'Beverages, fruit-flavored drink',
    ' drink,',
    'Carrot, dehydrated',
    'Snacks,'
    'Oil, almond',
    'Mushrooms, shiitake',
    'Cornstarch',
    'Cake,',
    'RALSTON TASTEEOS',
    'Cracker, meal',
    'Oil, spotted seal',
    'Oil, vegetable',
    'Tomatoes, sun dried',
    'pork, '
    'Oil, safflower',
    'Oil, canola',    
    'Baking chocolate',
    'GENERAL MILLS,',
    'Fat, turkey',
    'Rose Hips',
    'Seeds, pumpkin',
    
]

# %%
# EXCLUDED_FOOD_NAME = [



# ]
# EXCLUDED_FOOD_NAME_PART = []

# %%
data['SRLegacyFoods'][0]['foodNutrients'][0]['nutrient']['name']


# Exclude foods with these regex patterns in their names
# EXCLUDED_PATTERNS = 

# Extract all nutrient names from all foods
nutrient_names = set()
for food in data['SRLegacyFoods']:
    for nutrient in food['foodNutrients']:
        nutrient_names.add(nutrient['nutrient']['name'])

# # Print the nutrient names
for nutrient_name in nutrient_names:
    print(nutrient_name)
# Out:
# Carotene, beta
# Alanine
# SFA 16:0
# Fatty acids, total monounsaturated
# MUFA 17:1
# Fatty acids, total trans-monoenoic
# SFA 4:0
# Vitamin A, RAE
# Manganese, Mn
# PUFA 20:3 n-3
# Vitamin C, total ascorbic acid
# Tyrosine
# Fatty acids, total polyunsaturated
# Proline
# Fatty acids, total saturated
# Alcohol, ethyl
# Water
# PUFA 18:2 i
# Cholesterol
# MUFA 24:1 c
# Magnesium, Mg
# Stigmasterol
# MUFA 18:1 c
# Vitamin K (Menaquinone-4)
# PUFA 18:3 n-6 c,c,c
# PUFA 20:3
# Vitamin B-6
# Beta-sitosterol
# Caffeine
# Lutein + zeaxanthin
# Cystine
# PUFA 22:5 n-3 (DPA)
# PUFA 18:2 CLAs
# Vitamin B-12
# Niacin
# Total lipid (fat)
# Vitamin E, added
# Fructose
# MUFA 15:1
# Theobromine
# Glycine
# Thiamin
# Tryptophan
# Vitamin D3 (cholecalciferol)
# Serine
# Tocotrienol, gamma
# Vitamin B-12, added
# TFA 18:1 t
# Lysine
# PUFA 20:3 n-6
# Fiber, total dietary
# Retinol
# Tocopherol, delta
# Sodium, Na
# Tocopherol, gamma
# Pantothenic acid
# Vitamin A, IU
# Betaine
# SFA 6:0
# Glucose
# MUFA 16:1 c
# SFA 22:0
# PUFA 18:2 n-6 c,c
# MUFA 22:1 c
# Starch
# PUFA 20:2 n-6 c,c
# Selenium, Se
# SFA 8:0
# SFA 14:0
# Galactose
# Vitamin D (D2 + D3)
# PUFA 18:2
# Hydroxyproline
# Folate, food
# Arginine
# Tocotrienol, alpha
# SFA 13:0
# Methionine
# PUFA 18:4
# Energy
# PUFA 2:4 n-6
# PUFA 22:6 n-3 (DHA)
# SFA 17:0
# Lycopene
# Calcium, Ca
# Aspartic acid
# Folic acid
# Vitamin E (alpha-tocopherol)
# TFA 16:1 t
# Vitamin D (D2 + D3), International Units
# MUFA 16:1
# Isoleucine
# Valine
# Zinc, Zn
# Iron, Fe
# SFA 20:0
# PUFA 18:3 n-3 c,c,c (ALA)
# Ash
# TFA 18:2 t not further defined
# MUFA 14:1
# Fatty acids, total trans-polyenoic
# Copper, Cu
# Tocotrienol, beta
# Phenylalanine
# Vitamin K (phylloquinone)
# Sugars, total including NLEA
# SFA 24:0
# PUFA 22:4
# TFA 18:2 t,t
# Vitamin K (Dihydrophylloquinone)
# SFA 15:0
# Vitamin D2 (ergocalciferol)
# MUFA 18:1
# Maltose
# Threonine
# Leucine
# SFA 10:0
# PUFA 20:4
# Choline, total
# SFA 18:0
# Tocotrienol, delta
# Phosphorus, P
# PUFA 18:3
# MUFA 18:1-11 t (18:1t n-7)
# Carbohydrate, by difference
# Folate, total
# TFA 22:1 t
# Tocopherol, beta
# Histidine
# Folate, DFE
# PUFA 18:3i
# MUFA 22:1
# Carotene, alpha
# Fluoride, F
# Riboflavin
# PUFA 2:5 n-3 (EPA)
# Cryptoxanthin, beta
# Lactose
# PUFA 21:5
# Potassium, K
# Protein
# Fatty acids, total trans
# SFA 12:0
# Glutamic acid
# Phytosterols
# Sucrose
# MUFA 20:1
# Campesterol

# %%
EXCLUDED_FOOD_NAME_PART
# Out:
# ['Tortilla ',
#  'Candy, ',
#  'Dandelion ',
#  ', eel',
#  'Nutritional powder mix',
#  ' chips',
#  'Sun-dried ',
#  'Yeast extract spread',
#  ' Toddler ',
#  'Coffee, ',
#  'yolk only',
#  ' carp',
#  'Pizza ',
#  'Pork skin rinds',
#  ' canned,',
#  ' sauce,',
#  'Vegetable, dried',
#  'Chitterlings',
#  'Cookie, ',
#  'Crackers, ',
#  ' trout',
#  'Kidney',
#  'Spaghetti sauce',
#  'Vegetable mixture',
#  'Brains',
#  'Caviar',
#  'Fruit flavored drink',
#  'Liver, beef',
#  'Sloppy joe',
#  'Rice cake',
#  'Popcorn',
#  'Nutrition bar',
#  'Melba toast',
#  'Chocolate beverage powder',
#  ' sauce',
#  'Vegetarian chili, made with meat substitute',
#  'Topping from cheese pizza',
#  'Chips',
#  'Tea, iced, instant, black, unsweetened, dry',
#  "O's",
#  'rice crispy',
#  "Cereal, K's, plain",
#  'Cereal, oat bunches',
#  'Cereal, plain puffs',
#  ', mackerel',
#  'MALT O MEAL',
#  'Protein powder',
#  'fortified',
#  ' with honey',
#  'Infant formula,',
#  ' liver,',
#  'Babyfood, ',
#  'Spices, thyme, drie',
#  'Parmesan',
#  'shredded wheat',
#  'Winter squash',
#  'Rice crackers',
#  'Spices, ',
#  'Acerola',
#  'Candies',
#  ', canned',
#  'malt-o-meal',
#  ' oyster',
#  'halibut',
#  'CREAM OF WHEAT',
#  'QUAKER, QUAKER',
#  'Desserts',
#  'protein',
#  'cottonseed flour',
#  'Frostings',
#  'Mollusks',
#  'Bacon ',
#  'Fish oil, cod liver',
#  ' cod,',
#  'Corn flour',
#  'Cookies',
#  ' tea',
#  'Oil, beluga',
#  'Fish, salmon, chum, dried',
#  'Fat, chicken',
#  'pork skins',
#  'Seeds, cottonseed meal',
#  'Margarine',
#  'Egg, yolk, dried',
#  'Egg, white, dried',
#  'industrial',
#  'Oil, soybean lecithin',
#  'Oil, hazelnut',
#  'Oil, PAM cooking spray, original',
#  'Oil, sunflower',
#  'Fat, beef tallow',
#  'Oil, whale, bowhead',
#  'Beverages, fruit-flavored drink',
#  ' drink,',
#  'Carrot, dehydrated',
#  'Snacks,Oil, almond',
#  'Mushrooms, shiitake',
#  'Cornstarch',
#  'Cake,',
#  'RALSTON TASTEEOS',
#  'Cracker, meal',
#  'Oil, spotted seal',
#  'Oil, vegetable',
#  'Tomatoes, sun dried',
#  'pork, Oil, safflower',
#  'Oil, canola',
#  'Baking chocolate',
#  'GENERAL MILLS,',
#  'Fat, turkey',
#  'Rose Hips',
#  'Seeds, pumpkin']

# %%
data['SRLegacyFoods'][0]['description']
# extract all food descriptions
food_descriptions = set()
for food in data['SRLegacyFoods']:
    added = False
    if not any(excluded_name.lower() == food['description'].lower() for excluded_name in EXCLUDED_FOOD_NAME):
        if not any(excluded_name_part.lower() in food['description'].lower() for excluded_name_part in EXCLUDED_FOOD_NAME_PART):
            food_descriptions.add(food['description'])
            added = True
    if not added:
        pass
        # print excluded food
        # print("Excluded food: ", food['description'])
# Print the number of unique food descriptions formatted
print(f'Number of unique food descriptions: {len(food_descriptions)}')
# 4820 is ok
# Out:
# Number of unique food descriptions: 4060

# %%
# Extract all nutrient names from all foods in format like this:
# nutrients = {
#     'Oats': {'Calories': 389, 'Protein': 16.9, 'Fat': 6.9, 'Carbs': 66.3},
#     'Milk': {'Calories': 42, 'Protein': 3.4, 'Fat': 1.0, 'Carbs': 5.0},
#     'Banana': {'Calories': 89, 'Protein': 1.1, 'Fat': 0.3, 'Carbs': 22.8}
# }
# data['SRLegacyFoods'][0]['foodNutrients'][0]
nutrients = {}
for food in data['SRLegacyFoods']:
    food_name = food['description']
    nutrients[food_name] = {}
    for nutrient in food['foodNutrients']:
        nutrient_name = nutrient['nutrient']['name']
        nutrient_value = nutrient['amount']
        nutrients[food_name][nutrient_name] = nutrient_value



# define function that build dictionary with food name as key and dictionary of nutrients as value, but keep only provided nutrient names
def build_nutrients(data, nutrient_names):
    nutrients = {}
    measurements = {}
    for food in (data['SRLegacyFoods']):
        food_name = food['description']
        if not food_name in food_descriptions:
            continue
        nutrients_object = {}
        has_energy = False
        for nutrient in food['foodNutrients']:
            nutrient_name = nutrient['nutrient']['name']
            if nutrient_name in nutrient_names:
                multipler = 1
                if nutrient_name == 'Energy':
                    if  nutrient['nutrient']['unitName'] == 'kcal':
                        multipler = 1
                    elif nutrient['nutrient']['unitName'] == 'kJ':
                        multipler = 0.239006
                    else:
                        raise ValueError(f'Unknown unit for energy: "{nutrient["nutrient"]["unitName"]}"')
                    has_energy = True
                nutrient_value = nutrient['amount']
                nutrients_object[nutrient_name] = nutrient_value * multipler
                if nutrient_name not in measurements:
                    measurements[nutrient_name] = nutrient['nutrient']['unitName']
                elif measurements[nutrient_name] != nutrient['nutrient']['unitName'] and nutrient_name != 'Energy':
                    raise ValueError(f'Inconsistent unit for "{nutrient_name}": "{measurements[nutrient_name]}" and "{nutrient["nutrient"]["unitName"]}"')
        if has_energy:
            nutrients[food_name] = nutrients_object
        else:
            print(f'Food "{food_name}" does not have energy value')
    return nutrients, measurements

# nutreints, measurements = build_nutrients(data, ['Energy'])
# measurements

# %%
def filter_food(foods, food_name):
    # returns filtered list of foods, that contains food_name
    return [food for food in foods if food_name in food]

# %%
foods = list(food_descriptions)
nutrients, measurements = build_nutrients(data, [
    'Energy',
    'Carbohydrate, by difference',
    'Protein',
    'Total lipid (fat)',
    'Fiber, total dietary',
    'total dietary',
    'Sugars, total including NLEA',
    'Sodium, Na',
    'Cholesterol',
    'Vitamin A, RAE',
    'Vitamin C, total ascorbic acid',
    'Vitamin D (D2 + D3)',
    'Vitamin E (alpha-tocopherol)',
    'Vitamin K (phylloquinone)',
    'Folate, DFE',
    'Vitamin B-6',
    'Vitamin B-12',
    'Thiamin',
    'Riboflavin',
    'Niacin',
    'Calcium, Ca',
    'Iron, Fe',
    'Magnesium, Mg',
    'Zinc, Zn',
    'Potassium, K',
    'Fatty acids, total saturated',
    'Selenium, Se',
    'Carotene, beta',
    'Carotene, alpha',
    'Lycopene',
    'Zinc, Zn',
    'Copper, Cu',
    'Phosphorus, P',
    'Choline, total',
    'Lutein + zeaxanthin',
    'Folic acid',

])
len(nutrients), measurements
# Out:
# (4060,
#  {'Lutein + zeaxanthin': 'Âµg',
#   'Vitamin E (alpha-tocopherol)': 'mg',
#   'Folic acid': 'Âµg',
#   'Carotene, beta': 'Âµg',
#   'Carotene, alpha': 'Âµg',
#   'Lycopene': 'Âµg',
#   'Vitamin K (phylloquinone)': 'Âµg',
#   'Total lipid (fat)': 'g',
#   'Carbohydrate, by difference': 'g',
#   'Energy': 'kcal',
#   'Sugars, total including NLEA': 'g',
#   'Calcium, Ca': 'mg',
#   'Potassium, K': 'mg',
#   'Zinc, Zn': 'mg',
#   'Folate, DFE': 'Âµg',
#   'Niacin': 'mg',
#   'Vitamin B-6': 'mg',
#   'Choline, total': 'mg',
#   'Protein': 'g',
#   'Vitamin C, total ascorbic acid': 'mg',
#   'Thiamin': 'mg',
#   'Riboflavin': 'mg',
#   'Vitamin B-12': 'Âµg',
#   'Vitamin A, RAE': 'Âµg',
#   'Fiber, total dietary': 'g',
#   'Iron, Fe': 'mg',
#   'Magnesium, Mg': 'mg',
#   'Phosphorus, P': 'mg',
#   'Sodium, Na': 'mg',
#   'Copper, Cu': 'mg',
#   'Cholesterol': 'mg',
#   'Fatty acids, total saturated': 'g',
#   'Vitamin D (D2 + D3)': 'Âµg',
#   'Selenium, Se': 'Âµg'})

# %%
import pulp as pl

filtered_foods = list(food_descriptions)
# Define the problem
prob = pl.LpProblem("Meal_Planning_Problem", pl.LpMinimize)

# Create a dictionary of pulp variables with lower limit
food_vars = pl.LpVariable.dicts("Amount", filtered_foods, lowBound=0)


# Objective Function: minimize the total weight of foods
prob += pl.lpSum([food_vars[f] for f in filtered_foods]), "Total Weight of Food"

def add_nutrient_constraints(prob, nutrients, food_vars, nutrient_name, min_value, max_value):
    # Adding constraints for minimum nutrient values, if specified
    if min_value is not None:
        prob += pl.lpSum([(nutrients[f].get(nutrient_name, 0) * food_vars[f]) for f in filtered_foods] 
                         ) >= min_value, f"Min {nutrient_name}"
    # Adding constraints for maximum nutrient values, if specified
    if max_value is not None:
        prob += pl.lpSum([(nutrients[f].get(nutrient_name, 0) * food_vars[f]) for f in filtered_foods] 
                         ) <= max_value, f"Max {nutrient_name}"
calories = 2500
# [(0 if not nutrient_name in nutreints[f] else nutrients[f][nutrient_name]) * food_vars[f] for f in foods]z
add_nutrient_constraints(prob, nutrients, food_vars, 'Energy', calories, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Carbohydrate, by difference', calories * 0.45 / 4,  calories * 0.65 / 4)
add_nutrient_constraints(prob, nutrients, food_vars, 'Protein', calories * 0.1 / 4,  calories * 0.35 / 4)
add_nutrient_constraints(prob, nutrients, food_vars, 'Total lipid (fat)', calories * 0.0 / 9,  calories * 0.3 / 9)
add_nutrient_constraints(prob, nutrients, food_vars, 'Fiber, total dietary', 25, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Sugars, total including NLEA', None, 36)
add_nutrient_constraints(prob, nutrients, food_vars, 'Sodium, Na', None, 1500)
add_nutrient_constraints(prob, nutrients, food_vars, 'Cholesterol', None, 300)
add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin A, RAE', 900, 3000)
add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin C, total ascorbic acid', 90, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin D (D2 + D3)', 20, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin E (alpha-tocopherol)', 15, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin K (phylloquinone)', 120, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Folate, DFE', 400, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin B-6', 1.3, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin B-12', 2.4, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Thiamin', 1.2, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Riboflavin', 1.3, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Niacin', 16, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Calcium, Ca', 1200, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Iron, Fe', 8, 45)
add_nutrient_constraints(prob, nutrients, food_vars, 'Magnesium, Mg', 420, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Zinc, Zn', 11, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Potassium, K', 3400, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Fatty acids, total saturated', None, 20)
add_nutrient_constraints(prob, nutrients, food_vars, 'Selenium, Se', 55, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Carotene, beta', 10800, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Carotene, alpha', 21100, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Lycopene', 15000, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Copper, Cu', 1.4, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Phosphorus, P', 700 , None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Choline, total', 550, None)
add_nutrient_constraints(prob, nutrients, food_vars, 'Lutein + zeaxanthin', 10000, None)# can be lowered to 6000
add_nutrient_constraints(prob, nutrients, food_vars, 'Folic acid', 400, None)


# Solve the problem
prob.solve()
# Status of the problem
print("Status:", pl.LpStatus[prob.status])
if pl.LpStatus[prob.status] != 'Optimal':
    # show why it's infeasible
    infeasible_constraints = [c for c in prob.constraints.values() if c.value() != 0]
    # for c in infeasible_constraints:
    #     print(f"{c.name}: {c.value()}")
    raise ValueError("Could not find optimal solution")
# Output the results for each food variable with a non-zero value, formatted nicely
for v in prob.variables():
    if v.varValue > 0:
        # Remove 'Amount_' prefix and replace underscores with spaces in the food name
        formatted_name = v.name.replace("Amount_", "").replace("_", " ")
        print(f"{formatted_name} = {v.varValue * 100} grams")

# Print a divider line for clarity
print('-' * 40)

# # Display the calculated nutrient totals
for nutrient_name in measurements:
    # refactor code below to handle the case when nutrient is not present in food
    # nutrient_sum = sum(nutrients[f][nutrient_name] * food_vars[f].varValue for f in foods)
    # print(f"{nutrient_name}: {nutrient_sum} {measurements[nutrient_name]}")

    nutrient_sum = 0
    for f in foods:
        if nutrient_name in nutrients[f]:
            nutrient_sum += nutrients[f][nutrient_name] * food_vars[f].varValue
    print(f"{nutrient_name}: {nutrient_sum} {measurements[nutrient_name]}")
# Out:
# Status: Optimal
# Carrots, baby, raw = 186.00308 grams
# Egg, whole, dried = 17.445873 grams
# Mushrooms, brown, italian, or crimini, exposed to ultraviolet light, raw = 58.156715999999996 grams
# Noodles, chinese, cellophane or long rice (mung beans), dehydrated = 133.6713 grams
# Oil, wheat germ = 55.76987799999999 grams
# Peas, green, split, mature seeds, raw = 20.899388 grams
# Peppers, sweet, red, freeze dried = 2.4961922000000003 grams
# Pumpkin, cooked, boiled, drained, without salt = 511.56977 grams
# Quinoa, uncooked = 35.059381 grams
# Rice, white, long grain, precooked or instant, enriched, dry = 146.52015 grams
# Salmon, red (sockeye), filets with skin, smoked (Alaska Native) = 10.085334 grams
# Spaghetti, spinach, dry = 48.456314 grams
# Spinach, frozen, chopped or leaf, cooked, boiled, drained, without salt = 10.601768999999999 grams
# Tofu, dried frozen (koyadofu), prepared with calcium sulfate = 38.943477 grams
# Tomatoes, sun dried = 32.679739000000005 grams
# ----------------------------------------
# Lutein + zeaxanthin: 10000.00006698 Âµg
# Vitamin E (alpha-tocopherol): 89.9433198521 mg
# Folic acid: 400.00000950000003 Âµg
# Carotene, beta: 24793.867539339997 Âµg
# Carotene, alpha: 21099.99997946 Âµg
# Lycopene: 15000.000201 Âµg
# Vitamin K (phylloquinone): 186.937995312 Âµg
# Total lipid (fat): 83.33333375729997 g
# Carbohydrate, by difference: 374.0873628133 g
# Energy: 2500.000026217131 kcal
# Sugars, total including NLEA: 36.0000001305 g
# Calcium, Ca: 1200.000008608 mg
# Potassium, K: 3919.42756903 mg
# Zinc, Zn: 11.26463566292 mg
# Folate, DFE: 987.1694272579999 Âµg
# Niacin: 25.383777232610004 mg
# Vitamin B-6: 1.54552895838 mg
# Choline, total: 550.000001564 mg
# Protein: 74.6355731227 g
# Vitamin C, total ascorbic acid: 90.00000099900001 mg
# Thiamin: 2.7690433765100004 mg
# Riboflavin: 1.7814966082000003 mg
# Vitamin B-12: 2.4000000108000004 Âµg
# Vitamin A, RAE: 2999.9999952100006 Âµg
# Fiber, total dietary: 32.4636105386 g
# Iron, Fe: 29.148507522099997 mg
# Magnesium, Mg: 420.00000259600006 mg
# Phosphorus, P: 1375.0982450840002 mg
# Sodium, Na: 342.54003159599995 mg
# Copper, Cu: 2.9533456314600004 mg
# Cholesterol: 299.99999760000003 mg
# Fatty acids, total saturated: 16.184849337583998 g
# Vitamin D (D2 + D3): 19.999999863 Âµg
# Selenium, Se: 178.9391775634 Âµg

# %%
# import pulp as pl

# # Define the problem
# prob = pl.LpProblem("Meal_Planning_Problem", pl.LpMinimize)



# # Create a dictionary of pulp variables for food quantities with lower limit
# food_vars = pl.LpVariable.dicts("Amount", foods, lowBound=0)
# # Create a dictionary of binary variables to indicate whether a food item is included
# include_vars = pl.LpVariable.dicts("Include", foods, cat='Binary')

# # Objective Function: minimize the number of distinct products included
# prob += pl.lpSum([include_vars[f] for f in foods]), "Number of Distinct Products"

# # Ensure that the include variable is set to 1 if any amount of the food is used
# for f in foods:
#     prob += food_vars[f] <= include_vars[f] * 10000  # 10000 is a sufficiently large number
#     prob += food_vars[f] >= include_vars[f] * 0.1  # Assume 0.1g as the minimal amount to consider

# # Define a function to add nutrient constraints
# def add_nutrient_constraints(prob, nutrients, food_vars, nutrient_name, min_value, max_value):
#     if min_value is not None:
#         prob += pl.lpSum([(nutrients.get(f, {}).get(nutrient_name, 0) * food_vars[f]) for f in foods]) >= min_value, f"Min {nutrient_name}"
#     if max_value is not None:
#         prob += pl.lpSum([(nutrients.get(f, {}).get(nutrient_name, 0) * food_vars[f]) for f in foods]) <= max_value, f"Max {nutrient_name}"

# add_nutrient_constraints(prob, nutrients, food_vars, 'Energy', calories, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Carbohydrate, by difference', calories * 0.45 / 4,  calories * 0.65 / 4)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Protein', calories * 0.1 / 4,  calories * 0.35 / 4)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Total lipid (fat)', calories * 0.0 / 9,  calories * 0.3 / 9)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Fiber, total dietary', 25, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Sugars, total including NLEA', None, 36)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Sodium, Na', None, 1500)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Cholesterol', None, 300)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin A, RAE', 900, 3000)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin C, total ascorbic acid', 90, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin D (D2 + D3)', 20, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin E (alpha-tocopherol)', 15, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin K (phylloquinone)', 120, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Folate, DFE', 400, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin B-6', 1.3, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Vitamin B-12', 2.4, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Thiamin', 1.2, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Riboflavin', 1.3, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Niacin', 16, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Calcium, Ca', 1200, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Iron, Fe', 8, 45)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Magnesium, Mg', 420, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Zinc, Zn', 11, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Potassium, K', 3400, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Fatty acids, total saturated', None, 20)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Selenium, Se', 55, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Carotene, beta', 10800, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Carotene, alpha', 21100, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Lycopene', 15000, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Copper, Cu', 1.4, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Phosphorus, P', 700 , None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Choline, total', 550, None)
# add_nutrient_constraints(prob, nutrients, food_vars, 'Lutein + zeaxanthin', 10000, None)# can be lowered to 6000
# add_nutrient_constraints(prob, nutrients, food_vars, 'Folic acid', 400, None)


# # Solve the problem
# prob.solve()

# # Output the results
# print("Status:", pl.LpStatus[prob.status])
# if pl.LpStatus[prob.status] != 'Optimal':
#     raise ValueError("Could not find optimal solution")

# for v in prob.variables():
#     if 'Amount' in v.name and v.varValue > 0:
#         formatted_name = v.name.replace("Amount_", "").replace("_", " ")
#         print(f"{formatted_name} = {v.varValue:.2f} grams")

# # Print a divider line for clarity
# print('-' * 40)

# # # Display the calculated nutrient totals
# for nutrient_name in measurements:
#     # refactor code below to handle the case when nutrient is not present in food
#     # nutrient_sum = sum(nutrients[f][nutrient_name] * food_vars[f].varValue for f in foods)
#     # print(f"{nutrient_name}: {nutrient_sum} {measurements[nutrient_name]}")

#     nutrient_sum = 0
#     for f in foods:
#         if nutrient_name in nutrients[f]:
#             nutrient_sum += nutrients[f][nutrient_name] * food_vars[f].varValue
#     print(f"{nutrient_name}: {nutrient_sum} {measurements[nutrient_name]}")

# %%
foods
# Out:
# ['Tortillas, ready-to-bake or -fry, flour, refrigerated',
#  'Beef, round, tip round, roast, separable lean and fat, trimmed to 0" fat, choice, cooked, roasted',
#  'Beef, ground, 97% lean meat / 3% fat, crumbles, cooked, pan-browned',
#  'Yogurt, Greek, fruit, whole milk',
#  'Pheasant, raw, meat only',
#  'Emu, outside drum, raw',
#  'Milk, chocolate, fluid, commercial, whole, with added vitamin A and vitamin D',
#  'Sweet rolls, cheese',
#  'HOT POCKETS, meatballs & mozzarella stuffed sandwich, frozen',
#  'Beef, Australian, imported, grass-fed, round, bottom round steak/roast, boneless, separable lean only, raw',
#  'Game meat, raccoon, cooked, roasted',
#  'Beef, loin, tenderloin steak, boneless, separable lean and fat, trimmed to 0" fat, choice, cooked, grilled',
#  'Polish sausage, pork',
#  'Restaurant, family style, coleslaw',
#  'Turkey, light or dark meat, smoked, cooked, with skin, bone removed',
#  'Taquitos, frozen, chicken and cheese, oven-heated',
#  'Nuts, chestnuts, chinese, boiled and steamed',
#  'Seeds, sunflower seed butter, without salt',
#  'Bagels, cinnamon-raisin',
#  'Chicken, stewing, meat only, cooked, stewed',
#  'Milk, buttermilk, fluid, cultured, lowfat',
#  'Chicken, roasting, giblets, raw',
#  'Beef, loin, tenderloin roast, boneless, separable lean and fat, trimmed to 0" fat, select, raw',
#  'Chocolate-flavored hazelnut spread',
#  'Borage, cooked, boiled, drained, with salt',
#  'Danish pastry, raspberry, unenriched',
#  'Chicken, broilers or fryers, leg, meat only, cooked, stewed',
#  'Puddings, tapioca, ready-to-eat, fat free',
#  'Fish, catfish, channel, wild, raw',
#  'Chicken, roasting, giblets, cooked, simmered',
#  'Chicken, skin (drumsticks and thighs), with added solution, cooked, roasted',
#  'Egg substitute, powder',
#  'Veal, shoulder, blade, separable lean and fat, cooked, roasted',
#  'Cereals, QUAKER, Instant Grits, Butter flavor, dry',
#  'Dulce de Leche',
#  'Ice creams, BREYERS, No Sugar Added, Vanilla Chocolate Strawberry',
#  "Mother's loaf, pork",
#  'Beef, short loin, t-bone steak, bone-in, separable lean only, trimmed to 1/8" fat, choice, cooked, grilled',
#  'Toppings, butterscotch or caramel',
#  'Lamb, loin, separable lean only, trimmed to 1/4" fat, choice, cooked, broiled',
#  'Lamb, New Zealand, imported, tunnel-boned leg, chump off, shank off, separable lean and fat, cooked, slow roasted',
#  'Duck, young duckling, domesticated, White Pekin, leg, meat only, bone in, cooked without skin, braised',
#  'Pie, chocolate creme, commercially prepared',
#  'Lemonade, frozen concentrate, white, prepared with water',
#  'Beef, composite of trimmed retail cuts, separable lean only, trimmed to 0" fat, all grades, cooked',
#  'Fish, drum, freshwater, cooked, dry heat',
#  'Puddings, lemon, dry mix, instant',
#  'Beef, Australian, imported, Wagyu, external fat, Aust. marble score 4/5, raw',
#  'Soup, ramen noodle, chicken flavor, dry',
#  'Beef, loin, tenderloin roast, separable lean only, boneless, trimmed to 0" fat, select, cooked, roasted',
#  'Turkey, Ground, raw',
#  'Peppers, sweet, red, sauteed',
#  'KRAFT VELVEETA LIGHT Reduced Fat Pasteurized Process Cheese Product',
#  'Beverages, coffee substitute, cereal grain beverage, powder',
#  'Puddings, tapioca, dry mix, prepared with whole milk',
#  'Lettuce, butterhead (includes boston and bibb types), raw',
#  'Beef, chuck, shoulder clod, shoulder top and center steaks, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Chicken, feet, boiled',
#  'Frozen novelties, ice type, pop',
#  'Radishes, oriental, dried',
#  'Wheat, soft red winter',
#  'Alcoholic beverage, wine, table, white, Chardonnay',
#  'Potatoes, french fried, crinkle or regular cut, salt added in processing, frozen, as purchased',
#  'Beef, ribeye cap steak, boneless, separable lean only, trimmed to 0" fat, all grades, raw',
#  'Bread, multi-grain (includes whole-grain)',
#  'BURGER KING, Double Cheeseburger',
#  'Seeds, sesame seed kernels, toasted, without salt added (decorticated)',
#  'Ginger root, raw',
#  'Beef, loin, top sirloin cap steak, boneless, separable lean and fat, trimmed to 1/8" fat, all grades, cooked, grilled',
#  'Pizza, meat and vegetable topping, regular crust, frozen, cooked',
#  'Lasagna, Vegetable, frozen, baked',
#  'Cream substitute, powdered',
#  'Lamb, leg, whole (shank and sirloin), separable lean and fat, trimmed to 1/4" fat, choice, cooked, roasted',
#  'Beverages, Cocoa mix, powder, prepared with water',
#  'Muffins, blueberry, toaster-type',
#  'Tofu, firm, prepared with calcium sulfate and magnesium chloride (nigari)',
#  'Beef, ground, 75% lean meat / 25% fat, raw',
#  'Groundcherries, (cape-gooseberries or poha), raw',
#  'Beef, chuck, under blade pot roast, boneless, separable lean only, trimmed to 0" fat, all grades, cooked, braised',
#  'Beef, chuck, arm pot roast, separable lean and fat, trimmed to 1/8" fat, all grades, cooked, braised',
#  'Lamb, New Zealand, imported, neck chops, separable lean only, raw',
#  'Beef, variety meats and by-products, heart, cooked, simmered',
#  'Beef, chuck, clod roast, separable lean only, trimmed to 0" fat, select, cooked, roasted',
#  'Bologna, chicken, turkey, pork',
#  'Breakfast bar, corn flake crust with fruit',
#  'Beef, chuck eye Country-Style ribs, boneless, separable lean only, trimmed to 0" fat, choice, raw',
#  'Wocas, dried seeds, Oregon, yellow pond lily (Klamath)',
#  'Beef, chuck, arm pot roast, separable lean only, trimmed to 1/8" fat, choice, cooked, braised',
#  'Soybeans, mature seeds, sprouted, raw',
#  'Beef, loin, tenderloin steak, boneless, separable lean and fat, trimmed to 0" fat, select, raw',
#  'Puddings, lemon, dry mix, regular',
#  'Fish, pollock, Atlantic, raw',
#  'Beef, loin, tenderloin steak, boneless, separable lean and fat, trimmed to 0" fat, select, cooked, grilled',
#  'Veal, shoulder, blade chop, separable lean and fat, raw',
#  'Game meat, deer, shoulder clod, separable lean only, cooked, braised',
#  'Beverages, Malted drink mix, natural, with added nutrients, powder, prepared with whole milk',
#  'Puddings, vanilla, dry mix, regular, prepared with whole milk',
#  'Turkey, breast, from whole bird, meat only, with added solution, raw',
#  'Cheese, cottage, with vegetables',
#  'Pork, ground, 96% lean / 4% fat, cooked, pan-broiled',
#  'Luncheon slices, meatless',
#  "McDONALD'S, Side Salad",
#  'Chicken, broilers or fryers, dark meat, meat and skin, cooked, fried, flour',
#  'Beef, Australian, imported, Wagyu, rib, small end rib steak/roast, boneless, separable lean and fat, Aust. marble score 4/5, raw',
#  'Macaroni, vegetable, enriched, cooked',
#  'Melons, cantaloupe, raw',
#  'Pork sausage, link/patty, unprepared',
#  'Asparagus, frozen, unprepared',
#  'Teff, uncooked',
#  'Beef, loin, tenderloin steak, boneless, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Milk, filled, fluid, with blend of hydrogenated vegetable oils',
#  'Egg, whole, raw, fresh',
#  'Alcoholic beverage, wine, table, white',
#  'Chicken, broiler, rotisserie, BBQ, drumstick, meat only',
#  'Fast foods, submarine sandwich, ham on white bread with lettuce and tomato',
#  'Cabbage, chinese (pak-choi), cooked, boiled, drained, without salt',
#  'Beef, tenderloin, roast, separable lean and fat, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Seeds, cottonseed kernels, roasted (glandless)',
#  'Buffalo, free range, top round steak, raw (Shoshone Bannock)',
#  'Rice, white, medium-grain, cooked, unenriched',
#  'Beef, loin, top loin steak, boneless, lip off, separable lean only, trimmed to 0" fat, choice, cooked, grilled',
#  'Turkey, ground, 93% lean, 7% fat, patties, broiled',
#  'Lima beans, thin seeded (baby), mature seeds, cooked, boiled, without salt',
#  'Turkey, ground, 93% lean, 7% fat, raw',
#  'Lamb, Australian, imported, fresh, leg, center slice, bone-in, separable lean and fat, trimmed to 1/8" fat, raw',
#  'Braunschweiger (a liver sausage), pork',
#  'Rolls, dinner, rye',
#  'Jams and preserves, apricot',
#  'Veal, composite of trimmed retail cuts, separable fat, cooked',
#  'Pork, cured, ham with natural juices, spiral slice, boneless, separable lean only, unheated',
#  'Turkey, ground, fat free, raw',
#  'Peas, mature seeds, sprouted, raw',
#  'Mung beans, mature seeds, sprouted, cooked, stir-fried',
#  'Chickpeas (garbanzo beans, bengal gram), mature seeds, raw',
#  'Potatoes, mashed, dehydrated, granules without milk, dry form',
#  'Beef, chuck, clod roast, separable lean and fat, trimmed to 0" fat, all grades, cooked, roasted',
#  'Salami, cooked, turkey',
#  'Beef, round, full cut, separable lean only, trimmed to 1/4" fat, select, cooked, broiled',
#  'Pork, fresh, loin, blade (chops), bone-in, separable lean and fat, cooked, pan-fried',
#  'Beef, round, eye of round roast, boneless, separable lean and fat, trimmed to 0" fat, select, raw',
#  'Crustaceans, crayfish, mixed species, farmed, raw',
#  'Cabbage, savoy, cooked, boiled, drained, without salt',
#  'Beef, loin, tenderloin steak, boneless, separable lean only, trimmed to 0" fat, all grades, cooked, grilled',
#  'Fish, flatfish (flounder and sole species), raw',
#  'Bologna, meat and poultry',
#  'Wasabi, root, raw',
#  'Fish, catfish, channel, cooked, breaded and fried',
#  'Ice cream, light, soft serve, chocolate',
#  'Lamb, New Zealand, imported, frozen, loin, separable lean only, cooked, broiled',
#  'SILK Plain, soymilk',
#  'Turkey, all classes, breast, meat and skin, cooked, roasted',
#  'Pork, cured, ham, steak, boneless, extra lean, unheated',
#  'Beef, brisket, flat half, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  'Pork, cured, ham -- water added, shank, bone-in, separable lean and fat, heated, roasted',
#  'Winged beans, immature seeds, raw',
#  'Lamb, leg, sirloin half, separable lean and fat, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Nuts, mixed nuts, dry roasted, with peanuts, without salt added',
#  'Turkey, retail parts, thigh, meat only, raw',
#  'Beef, rib eye steak, boneless, lip off, separable lean only, trimmed to 0" fat, select, cooked, grilled',
#  'Beef, cured, breakfast strips, raw or unheated',
#  'Soursop, raw',
#  'Snacks, corn cakes',
#  'Cress, garden, cooked, boiled, drained, with salt',
#  'Alcoholic beverage, beer, light, low carb',
#  'Chicken, broilers or fryers, leg, meat and skin, cooked, stewed',
#  'Lamb, leg, shank half, separable lean and fat, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Pork, fresh, loin, sirloin (roasts), boneless, separable lean only, cooked, roasted',
#  'Puddings, lemon, dry mix, regular, with added oil, potassium, sodium',
#  'Chicken, broilers or fryers, back, meat only, cooked, roasted',
#  'Turkey, breast, from whole bird, meat only, with added solution, roasted',
#  'Oil, coconut',
#  'Lamb, New Zealand, imported, loin chop, separable lean only, cooked, fast fried',
#  'Frozen novelties, ice cream type, sundae, prepackaged',
#  'Beverages, chocolate malt, powder, prepared with fat free milk',
#  'Beets, raw',
#  'Cheese, romano',
#  'Veal, cubed for stew (leg and shoulder), separable lean only, raw',
#  'KFC, Fried Chicken, EXTRA CRISPY, Thigh, meat and skin with breading',
#  'Potatoes, raw, skin',
#  'Mangos, raw',
#  'Beef, plate steak, boneless, inside skirt, separable lean only, trimmed to 0" fat, select, raw',
#  'Bologna, chicken, pork',
#  'Cheese, mozzarella, low moisture, part-skim, shredded',
#  'Cheese, goat, hard type',
#  "DENNY'S, macaroni & cheese, from kid's menu",
#  'Puddings, rice, dry mix, prepared with 2% milk',
#  'Turkey, whole, meat only, cooked, roasted',
#  'Milk dessert, frozen, milk-fat free, chocolate',
#  'Snacks, corn cakes, very low sodium',
#  'Potatoes, french fried, cottage-cut, salt not added in processing, frozen, oven-heated',
#  'Peanuts, spanish, oil-roasted, without salt',
#  'Ice creams, chocolate, rich',
#  'Whale, beluga, meat, dried (Alaska Native)',
#  'Turkey, ground, 93% lean, 7% fat, pan-broiled crumbles',
#  'Beef, ground, 85% lean meat / 15% fat, crumbles, cooked, pan-browned',
#  'Beef, rib, back ribs, bone-in, separable lean and fat, trimmed to 0" fat, all grades, cooked, braised',
#  'Chicken, wing, frozen, glazed, barbecue flavored',
#  'Broccoli raab, cooked',
#  'Beef, rib, eye, small end (ribs 10-12), separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Cereals ready-to-eat, POST, GRAPE-NUTS Flakes',
#  'Turkey, dark meat from whole, meat and skin, with added solution, raw',
#  'Catsup, low sodium',
#  'Turkey, retail parts, thigh, meat and skin, raw',
#  'Fish, tilefish, raw',
#  "T.G.I. FRIDAY'S, macaroni & cheese, from kid's menu",
#  'Vinegar, distilled',
#  'Pork, cured, ham and water product, slice, boneless, separable lean only, heated, pan-broil',
#  'Game meat, bear, raw',
#  'Fast foods, submarine sandwich, steak and cheese on white bread with cheese, lettuce and tomato',
#  'Spinach, frozen, chopped or leaf, cooked, boiled, drained, with salt',
#  'Gravy, brown instant, dry',
#  'Pork, fresh, loin, top loin (chops), boneless, separable lean and fat, cooked, broiled',
#  'Puddings, banana, dry mix, regular, prepared with 2% milk',
#  'Beef, rib, large end (ribs 6-9), separable lean and fat, trimmed to 1/8" fat, prime, cooked, roasted',
#  'Muffins, English, wheat',
#  'Snack, Pretzel, hard chocolate coated',
#  'Soymilk, original and vanilla, light, unsweetened, with added calcium, vitamins A and D',
#  'Lamb, New Zealand, imported, ground lamb, cooked, braised',
#  'Cowpeas, leafy tips, cooked, boiled, drained, with salt',
#  'Bread, crumbs, dry, grated, plain',
#  'Wonton wrappers (includes egg roll wrappers)',
#  'French toast, prepared from recipe, made with low fat (2%) milk',
#  'Wheat, hard red winter',
#  'Chicken, broilers or fryers, wing, meat and skin, raw',
#  'Pie Crust, Cookie-type, Chocolate, Ready Crust',
#  'Oil, poppyseed',
#  'Barley malt flour',
#  'Strawberry-flavor beverage mix, powder',
#  'Turkey breast, low salt, prepackaged or deli, luncheon meat',
#  'Fast Foods, grilled chicken filet sandwich, with lettuce, tomato and spread',
#  'Tortillas, ready-to-bake or -fry, whole wheat',
#  'Snacks, granola bar, QUAKER, chewy, 90 Calorie Bar',
#  'Ostrich, tip trimmed, cooked',
#  'Peas, green, frozen, cooked, boiled, drained, without salt',
#  'Sausage, turkey, hot, smoked',
#  'Game meat, squirrel, cooked, roasted',
#  'Beverages, Kiwi Strawberry Juice Drink',
#  'Alcoholic beverage, wine, table, white, Pinot Gris (Grigio)',
#  'Egg substitute, liquid or frozen, fat free',
#  'Beef, round, tip round, roast, separable lean only, trimmed to 0" fat, select, raw',
#  'Cream puff, eclair, custard or cream filled, iced',
#  'Chicken, broilers or fryers, rotisserie, original seasoning, back, meat and skin, cooked',
#  'Beef, round, top round steak, boneless, separable lean only, trimmed to 0" fat, all grades, cooked, grilled',
#  'Pork, ground, 84% lean / 16% fat, raw',
#  'Chicken, thighs, frozen, breaded, reheated',
#  'Thuringer, cervelat, summer sausage, beef, pork',
#  'Bread, rye',
#  'Cereals, farina, unenriched, dry',
#  'BURGER KING, Chicken Strips',
#  'CHICK-FIL-A, chicken sandwich',
#  'Beef, round, eye of round, roast, separable lean and fat, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Pork, loin, leg cap steak, boneless, separable lean and fat, cooked, broiled',
#  'Beef, chuck eye Country-Style ribs, boneless, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Lamb, ground, raw',
#  'KFC, Fried Chicken, EXTRA CRISPY, Wing, meat only, skin and breading removed',
#  'Beef, chuck, under blade pot roast or steak, boneless, separable lean only, trimmed to 0" fat, choice, raw',
#  'Beef, New Zealand, imported, subcutaneous fat, cooked',
#  'Beef, chuck, under blade center steak, boneless, Denver Cut, separable lean only, trimmed to 0" fat, choice, raw',
#  'Water, non-carbonated, bottles, natural fruit flavors, sweetened with low calorie sweetener',
#  'Snacks, trail mix, tropical',
#  'Muffins, blueberry, toaster-type, toasted',
#  'Rice, white, medium-grain, enriched, cooked',
#  'Seaweed, laver, raw',
#  'Alcoholic beverage, pina colada, prepared-from-recipe',
#  'Seeds, sisymbrium sp. seeds, whole, dried',
#  'Turkey, whole, breast, meat only, cooked, roasted',
#  'Turkey, retail parts, breast, meat only, with added solution, cooked, roasted',
#  'Beef, short loin, t-bone steak, bone-in, separable lean only, trimmed to 1/8" fat, all grades, raw',
#  'Frankfurter, beef, pork, and turkey, fat free',
#  'Beef, top sirloin, steak, separable lean and fat, trimmed to 1/8" fat, choice, raw',
#  'Veal, shank, separable lean only, raw',
#  'Salad dressing, french dressing, fat-free',
#  'Fast Foods, Fried Chicken, Wing, meat and skin and breading',
#  'Pork, Leg sirloin tip roast, boneless, separable lean and fat, cooked, braised',
#  'Beef, shoulder pot roast, boneless, separable lean and fat, trimmed to 0" fat, select, cooked, braised',
#  'Pork, cured, ham with natural juices, spiral slice, boneless, separable lean and fat, heated, roasted',
#  'Corn, sweet, yellow, raw',
#  'Frybread, made with lard (Apache)',
#  'Rolls, french',
#  'Beef, round, eye of round steak, boneless, separable lean and fat, trimmed to 0" fat, all grades, cooked, grilled',
#  'Sweet potato leaves, cooked, steamed, without salt',
#  'Malt beverage, includes non-alcoholic beer',
#  'Chicken, skin (drumsticks and thighs), cooked, braised',
#  'Chicken, broilers or fryers, dark meat, meat and skin, cooked, fried, batter',
#  'Beef, round, eye of round steak, boneless, separable lean and fat, trimmed to 0" fat, select, raw',
#  'Pork sausage, link/patty, fully cooked, unheated',
#  'SILK Plus Omega-3 DHA, soymilk',
#  'Beef, short loin, top loin, steak, separable lean and fat, trimmed to 1/8" fat, all grades, raw',
#  'Pork, fresh, variety meats and by-products, pancreas, cooked, braised',
#  'Turkey, ground, 85% lean, 15% fat, patties, broiled',
#  'Breadfruit, raw',
#  'Meatballs, frozen, Italian style',
#  'Fish, shad, american, cooked, dry heat',
#  'Fish, salmon, sockeye, raw',
#  'Chicken, nuggets, white meat, precooked, frozen, not reheated',
#  'Chicken, broilers or fryers, breast, meat and skin, raw',
#  'Fish, whitefish, mixed species, raw',
#  'Puddings, chocolate flavor, low calorie, regular, dry mix',
#  'Lotus root, cooked, boiled, drained, with salt',
#  'Poultry, mechanically deboned, from backs and necks with skin, raw',
#  'Beef, shoulder top blade steak, boneless, separable lean and fat, trimmed to 0" fat, select, cooked, grilled',
#  'Beef, round, eye of round roast, boneless, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Peppered loaf, pork, beef',
#  'Chicken, broilers or fryers, rotisserie, original seasoning, thigh, meat and skin, cooked',
#  'Cereals, WHEATENA, cooked with water',
#  'Lamb, New Zealand, imported, fore-shank, separable lean and fat, raw',
#  'CRACKER BARREL, farm raised catfish platter',
#  'Pork, cured, ham -- water added, shank, bone-in, separable lean and fat, unheated',
#  'Waterchestnuts, chinese, (matai), raw',
#  'Pie crust, deep dish, frozen, unbaked, made with enriched flour',
#  'Gravy, brown, dry',
#  'Bread, roll, Mexican, bollilo',
#  'Beef, composite of trimmed retail cuts, separable lean only, trimmed to 1/8" fat, choice, raw',
#  'Nuts, walnuts, glazed',
#  'Shortening household soybean (hydrogenated) and palm',
#  'Milk substitutes, fluid, with lauric acid oil',
#  'Beef, rib eye steak/roast, bone-in, lip-on, separable lean only, trimmed to 1/8" fat, select, raw',
#  'Sweet Potato puffs, frozen, unprepared',
#  'Egg, whole, raw, frozen, salted, pasteurized',
#  'Salmon, red (sockeye), filets with skin, smoked (Alaska Native)',
#  'Pizza, cheese topping, thin crust, frozen, cooked',
#  'Peas, edible-podded, frozen, unprepared',
#  'Beans, great northern, mature seeds, cooked, boiled, without salt',
#  'Beef, composite of trimmed retail cuts, separable lean and fat, trimmed to 0" fat, select, cooked',
#  'Pork, fresh, loin, top loin (chops), boneless, separable lean only, with added solution, raw',
#  'Carrots, baby, raw',
#  'LITTLE CAESARS 14" Original Round Meat and Vegetable Pizza, Regular Crust',
#  'Salad Dressing, mayonnaise, light, SMART BALANCE, Omega Plus light',
#  'Eggplant, pickled',
#  'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie, fat-free',
#  'Raspberries, puree, seedless',
#  'Chewing gum, sugarless',
#  'Sausage, Polish, pork and beef, smoked',
#  'SILK Vanilla soy yogurt (single serving size)',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, fried, flour',
#  'Beef, shoulder pot roast, boneless, separable lean only, trimmed to 0" fat, choice, cooked, braised',
#  'Chicken, stewing, giblets, cooked, simmered',
#  'Beef, plate steak, boneless, inside skirt, separable lean and fat, trimmed to 0" fat, all grades, cooked, grilled',
#  'Spinach souffle',
#  'Veal, Australian, rib, rib roast, separable lean and fat, raw',
#  'Snacks, corn-based, extruded, onion-flavor',
#  'Egg, white, raw, fresh',
#  'Radish seeds, sprouted, raw',
#  'Fish, roe, mixed species, cooked, dry heat',
#  'Game meat, boar, wild, raw',
#  'Alcoholic beverage, beer, light, BUDWEISER SELECT',
#  'Cherimoya, raw',
#  'Beef, chuck, blade roast, separable lean only, trimmed to 0" fat, all grades, cooked, braised',
#  'Sauce, pesto, ready-to-serve, refrigerated',
#  'Mungo beans, mature seeds, raw',
#  'Pork, fresh, loin, top loin (chops), boneless, separable lean and fat, cooked, pan-fried',
#  'Squash, winter, all varieties, cooked, baked, with salt',
#  'Beverages, carbonated, lemon-lime soda, no caffeine',
#  'Lamb, leg, whole (shank and sirloin), separable lean and fat, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Beef, top sirloin, steak, separable lean and fat, trimmed to 1/8" fat, choice, cooked, broiled',
#  'Bread, Italian',
#  'SUBWAY, roast beef sub on white bread with lettuce and tomato',
#  'Mountain yam, hawaii, raw',
#  'Game meat, elk, raw',
#  'Vitasoy USA, Organic Nasoya Extra Firm Tofu',
#  'Jute, potherb, cooked, boiled, drained, with salt',
#  'Beef, rib, large end (ribs 6-9), separable lean and fat, trimmed to 1/8" fat, choice, cooked, broiled',
#  'Nopales, cooked, without salt',
#  'Wheat flour, white, all-purpose, enriched, bleached',
#  'Game meat, elk, cooked, roasted',
#  'Jams, preserves, marmalades, sweetened with fruit juice',
#  'Turkey and gravy, frozen',
#  "Nabisco, Nabisco Snackwell's Fat Free Devil's Food Cookie Cakes",
#  'Peppers, sweet, red, freeze-dried',
#  'Beef, rib, large end (ribs 6-9), separable lean and fat, trimmed to 1/8" fat, all grades, raw',
#  'Cauliflower, green, cooked, no salt added',
#  'Lamb, shoulder, arm, separable lean only, trimmed to 1/4" fat, choice, cooked, roasted',
#  'Veal, sirloin, separable lean and fat, cooked, roasted',
#  'Nuts, pistachio nuts, dry roasted, with salt added',
#  'Sauce, barbecue',
#  'Keikitos (muffins), Latino bakery item',
#  'Fast Foods, crispy chicken filet sandwich, with lettuce and mayonnaise',
#  'Sauce, horseradish',
#  'Beef, brisket, flat half, separable lean only, trimmed to 0" fat, choice, cooked, braised',
#  'Fish, tuna, fresh, bluefin, cooked, dry heat',
#  'Pork, fresh, variety meats and by-products, spleen, raw',
#  "McDONALD'S, Sausage Biscuit with Egg",
#  'Peas, mature seeds, sprouted, cooked, boiled, drained, with salt',
#  'Chicken, broilers or fryers, thigh, meat and skin, cooked, roasted',
#  'Pasta, cooked, enriched, with added salt',
#  'Beef, New Zealand, imported, tenderloin, separable lean only, cooked, fast fried',
#  'Lamb, Australian, imported, fresh, leg, center slice, bone-in, separable lean and fat, trimmed to 1/8" fat, cooked, broiled',
#  'Chicken, broilers or fryers, light meat, meat and skin, raw',
#  'Beef, New Zealand, imported, tenderloin, separable lean and fat, cooked, fast fried',
#  'Beef, round, knuckle, tip center, steak, separable lean and fat, trimmed to 0" fat, choice, cooked, grilled',
#  'SMART SOUP, Indian Bean Masala',
#  'Salami, dry or hard, pork, beef',
#  'Lamb, New Zealand, imported, tunnel-boned leg, chump off, shank off, separable lean only, cooked, slow roasted',
#  'Rice noodles, cooked',
#  'Soup, tomato, low sodium, with water',
#  "DENNY'S, fish fillet, battered or breaded, fried",
#  'Frozen novelties, ice type, lime',
#  'Lamb, Australian, imported, fresh, rack, roast, frenched, denuded, bone-in, separable lean only, trimmed to 0" fat, cooked, roasted',
#  'Chicken, broiler, rotisserie, BBQ, skin',
#  'Beef, brisket, flat half, boneless, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Pork, fresh, loin, center rib (roasts), bone-in, separable lean and fat, cooked, roasted',
#  'Duck, young duckling, domesticated, White Pekin, breast, meat only, boneless, cooked without skin, broiled',
#  'Beef, chuck, mock tender steak, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  'Nuts, macadamia nuts, raw',
#  'Puddings, rice, ready-to-eat',
#  'Snacks, granola bars, soft, uncoated, plain',
#  'Squash, zucchini, baby, raw',
#  'Pancakes, plain, dry mix, complete (includes buttermilk)',
#  'Lamb, New Zealand, imported, neck chops, separable lean only, cooked, braised',
#  'Pork, cured, ham and water product, shank, bone-in, separable lean and fat, unheated',
#  'Veal, shank (fore and hind), separable lean and fat, cooked, braised',
#  'Peppers, hot chili, red, raw',
#  'Soybeans, mature seeds, sprouted, cooked, steamed',
#  'Turkey, drumstick, from whole bird, meat only, roasted',
#  'Pork, cured, ham with natural juices, whole, boneless, separable lean and fat, heated, roasted',
#  'Gourd, dishcloth (towelgourd), cooked, boiled, drained, with salt',
#  'BURGER KING, Onion Rings',
#  'Bread, french or vienna (includes sourdough)',
#  'Salad dressing, italian dressing, commercial, regular',
#  'Lamb, Australian, imported, fresh, rib chop, frenched, denuded, bone-in, separable lean and fat, trimmed to 0" fat, cooked, grilled',
#  'Beef, ground, 75% lean meat / 25% fat, patty, cooked, pan-broiled',
#  'Beef, tenderloin, steak, separable lean only, trimmed to 1/8" fat, choice, cooked, broiled',
#  'Fish, sablefish, cooked, dry heat',
#  'Bread, blue corn, somiviki (Hopi)',
#  'Lasagna, cheese, frozen, prepared',
#  'Mung beans, mature seeds, cooked, boiled, without salt',
#  'Caribou, hind quarter meat, raw (Alaska Native)',
#  'Pork, fresh, separable fat, raw',
#  'Lemonade, frozen concentrate, pink',
#  'Beef, round, top round roast, boneless, separable lean and fat, trimmed to 0" fat, all grades, cooked, roasted',
#  'Turkey, whole, wing, meat only, raw',
#  'Pasta, gluten-free, brown rice flour, cooked, TINKYADA',
#  'Snacks, corn-based, extruded, puffs or twists, cheese-flavor, unenriched',
#  'Pork, fresh, loin, blade (chops), bone-in, separable lean only, cooked, braised',
#  'Broccoli, chinese, cooked',
#  'Java-plum, (jambolan), raw',
#  'Bamboo shoots, cooked, boiled, drained, without salt',
#  'Egg, goose, whole, fresh, raw',
#  'Fish, salmon, Atlantic, wild, raw',
#  'Potatoes, frozen, french fried, par fried, cottage-cut, prepared, heated in oven, with salt',
#  'Puddings, chocolate flavor, low calorie, instant, dry mix',
#  'Beef, chuck, mock tender steak, separable lean and fat, trimmed to 0" fat, all grades, cooked, broiled',
#  'Oscar Mayer, Ham (chopped with natural juice)',
#  'Beef, top sirloin, steak, separable lean only, trimmed to 1/8" fat, all grades, cooked, broiled',
#  'Seal, bearded (Oogruk), meat, partially dried (Alaska Native)',
#  'Yogurt, Greek, 2%fat, coconut blend, CHOBANI',
#  'Beef, top loin filet, boneless, separable lean only, trimmed to 1/8" fat, select, cooked, grilled',
#  'Radishes, white icicle, raw',
#  "DENNY'S, spaghetti and meatballs",
#  'Beef, loin, tenderloin roast, boneless, separable lean only, trimmed to 0" fat, all grades, raw',
#  'Yogurt, chocolate, nonfat milk',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, stewed',
#  'Asparagus, raw',
#  'Beef, plate steak, boneless, outside skirt, separable lean only, trimmed to 0" fat, select, raw',
#  'Restaurant, Italian, lasagna with meat',
#  'Alcoholic Beverage, wine, table, red, Merlot',
#  'Squash, winter, butternut, frozen, cooked, boiled, without salt',
#  'Beef, shank crosscuts, separable lean only, trimmed to 1/4" fat, choice, cooked, simmered',
#  'Apples, dried, sulfured, stewed, without added sugar',
#  'Beef, rib eye roast, bone-in, lip-on, separable lean and fat, trimmed to 1/8" fat, select, cooked, roasted',
#  'Chicken breast, deli, rotisserie seasoned, sliced, prepackaged',
#  'Turkey breast, pre-basted, meat and skin, cooked, roasted',
#  'Chicken, broiler, rotisserie, BBQ, wing, meat and skin',
#  'Fish, pike, walleye, raw',
#  'Beef, top loin petite roast, boneless, separable lean only, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Beef, rib, back ribs, bone-in, separable lean only, trimmed to 0" fat, all grades, raw',
#  'Lamb, Australian, imported, fresh, leg, hindshank, heel on, bone-in, separable lean and fat, trimmed to 1/8" fat, raw',
#  'Chicken, dark meat, drumstick, meat and skin, with added solution, cooked, braised',
#  'Blueberries, raw',
#  'Snacks, granola bar, with coconut, chocolate coated',
#  'Chicken, broilers or fryers, meat and skin and giblets and neck, cooked, fried, flour',
#  'Pork, cured, ham with natural juices, slice, bone-in, separable lean and fat, unheated',
#  'Lamb, shoulder, blade, separable lean only, trimmed to 1/4" fat, choice, cooked, braised',
#  'Beef, composite of trimmed retail cuts, separable lean and fat, trimmed to 1/8" fat, select, cooked',
#  'Beef, rib, back ribs, bone-in, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  'Beef, loin, top sirloin cap steak, boneless, separable lean only, trimmed to 1/8" fat, choice, cooked, grilled',
#  'Turkey, back, from whole bird, meat only, with added solution, raw',
#  'Beef, New Zealand, imported, manufacturing beef, raw',
#  'Beef, ground, 70% lean meat / 30% fat, crumbles, cooked, pan-browned',
#  'Oil, cooking and salad, ENOVA, 80% diglycerides',
#  'Beef, chuck, under blade pot roast or steak, boneless, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Bamboo shoots, raw',
#  'Beef, round, eye of round steak, boneless, separable lean only, trimmed to 0" fat, choice, raw',
#  'Fast foods, nachos, with cheese',
#  'Lima beans, immature seeds, raw',
#  'Beef, round, knuckle, tip side, steak, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Beef, loin, tenderloin roast, boneless, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  'Blueberries, dried, sweetened',
#  'Sausage, pork, chorizo, link or ground, raw',
#  'Pork, fresh, loin, top loin (roasts), boneless, separable lean and fat, cooked, roasted',
#  'Salad dressing, ranch dressing, regular',
#  'Milk shakes, thick chocolate',
#  'Agave, dried (Southwest)',
#  'CHICK-FIL-A, hash browns',
#  'Beef, chuck, clod roast, separable lean only, trimmed to 0" fat, all grades, cooked, roasted',
#  'Yogurt, Greek, 2% fat,mixed berry blend, CHOBANI',
#  'Beerwurst, beer salami, pork and beef',
#  'Cereals ready-to-eat, POST SELECTS Blueberry Morning',
#  'Cheese, cottage, lowfat, 1% milkfat, with vegetables',
#  'Fish, pompano, florida, raw',
#  'TACO BELL, BURRITO SUPREME with beef',
#  'Sweetener, syrup, agave',
#  'Roselle, raw',
#  'Hormel Pillow Pak Sliced Turkey Pepperoni',
#  'Formulated bar, LUNA BAR, NUTZ OVER CHOCOLATE',
#  'Snacks, granola bars, hard, plain',
#  'Alcoholic Beverage, wine, table, red, Mouvedre',
#  'Beef, brisket, point half, separable lean and fat, trimmed to 1/8" fat, all grades, cooked, braised',
#  'Duck, young duckling, domesticated, White Pekin, breast, meat and skin, boneless, cooked, roasted',
#  'Okra, frozen, unprepared',
#  "Snacks, KELLOGG, KELLOGG'S RICE KRISPIES TREATS Squares",
#  'Pie Crust, Cookie-type, Graham Cracker, Ready Crust',
#  'Chicken, broilers or fryers, thigh, meat and skin, raw',
#  'Turkey, retail parts, drumstick, meat only, cooked, roasted',
#  'Eggplant, cooked, boiled, drained, without salt',
#  'Seeds, chia seeds, dried',
#  'Snacks, granola bars, hard, chocolate chip',
#  'Milk, nonfat, fluid, with added vitamin A and vitamin D (fat free or skim)',
#  'Fish oil, herring',
#  'Oil, soybean, salad or cooking, (partially hydrogenated) and cottonseed',
#  'Cocoa, dry powder, hi-fat or breakfast, processed with alkali',
#  'Cereals ready-to-eat, QUAKER, Toasted Multigrain Crisps',
#  'Mush, blue corn with ash (Navajo)',
#  'Tomatoes, yellow, raw',
#  'Rolls, hamburger or hotdog, plain',
#  'Garlic bread, frozen',
#  'Muffins, English, raisin-cinnamon, toasted (includes apple-cinnamon)',
#  'Lamb, Australian, imported, fresh, leg, whole (shank and sirloin), separable lean and fat, trimmed to 1/8" fat, raw',
#  'Winged beans, immature seeds, cooked, boiled, drained, without salt',
#  'Toppings, pineapple',
#  'Egg, quail, whole, fresh, raw',
#  'Tomatoes, green, raw',
#  'Fish oil, menhaden, fully hydrogenated',
#  'Soup, beef broth, cubed, prepared with water',
#  'Beef, rib, whole (ribs 6-12), separable lean and fat, trimmed to 1/8" fat, all grades, cooked, broiled',
#  'Canada Goose, breast meat only, skinless, raw',
#  'Potato soup, instant, dry mix',
#  'Shallots, raw',
#  'Beef, chuck eye steak, boneless, separable lean and fat, trimmed to 0" fat, choice, cooked, grilled',
#  'Bratwurst, pork, beef, link',
#  'SUBWAY, meatball marinara sub on white bread (no toppings)',
#  'Beans, navy, mature seeds, raw',
#  'Pork, fresh, loin, whole, separable lean only, raw',
#  'Sweetener, herbal extract powder from Stevia leaf',
#  'Fish, spot, raw',
#  'Cereals, QUAKER, Instant Grits Product with American Cheese Flavor, dry',
#  'Mung beans, mature seeds, sprouted, cooked, boiled, drained, with salt',
#  'Chicken, roasting, meat and skin and giblets and neck, raw',
#  'Whale, bowhead, skin and subcutaneous fat (muktuk) (Alaska Native)',
#  'Fast foods, griddle cake sandwich, egg, cheese, and bacon',
#  'Kielbasa, fully cooked, pan-fried',
#  'Croissants, apple',
#  'Milk, human, mature, fluid (For Reference Only)',
#  'Nuts, chestnuts, european, raw, peeled',
#  'Alcoholic beverage, wine, table, red',
#  'Salad dressing, italian dressing, fat-free',
#  'Fast foods, griddle cake sandwich, egg, cheese, and sausage',
#  'Potatoes, white, flesh and skin, baked',
#  'Seeds, breadfruit seeds, raw',
#  'Alcoholic beverage, rice (sake)',
#  'Chicken, dark meat, drumstick, meat and skin, with added solution, cooked, roasted',
#  'Fish, salmon, coho, wild, cooked, moist heat',
#  'Plums, dried (prunes), stewed, without added sugar',
#  'Beef, top sirloin, steak, separable lean and fat, trimmed to 1/8" fat, select, raw',
#  'Game meat, antelope, raw',
#  'Squash, winter, hubbard, cooked, boiled, mashed, with salt',
#  'Soybeans, mature seeds, sprouted, cooked, steamed, with salt',
#  'Beef, brisket, flat half, separable lean and fat, trimmed to 0" fat, select, cooked, braised',
#  'KRAFT VELVEETA Pasteurized Process Cheese Spread',
#  'Beef, New Zealand, imported, intermuscular fat, cooked',
#  'Beef, tenderloin, steak, separable lean and fat, trimmed to 1/8" fat, choice, cooked, broiled',
#  'Ham, smoked, extra lean, low sodium',
#  'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, cooked',
#  'Lamb, foreshank, separable lean and fat, trimmed to 1/8" fat, cooked, braised',
#  'Lamb, composite of trimmed retail cuts, separable lean and fat, trimmed to 1/4" fat, choice, raw',
#  'Pork, fresh, backribs, separable lean and fat, cooked, roasted',
#  'Alcoholic beverage, wine, dessert, sweet',
#  'Beef, bologna, reduced sodium',
#  'Pork, fresh, loin, top loin (chops), boneless, separable lean only, raw',
#  'Pork, fresh, loin, center rib (chops), boneless, separable lean only, cooked, braised',
#  'Restaurant, Mexican, cheese tamales',
#  'Pork, ground, 84% lean / 16% fat, cooked, crumbles',
#  'Beef, round, tip round, separable lean and fat, trimmed to 1/8" fat, choice, raw',
#  'Peppers, serrano, raw',
#  'Pork, cured, ham with natural juices, whole, boneless, separable lean only, unheated',
#  'Lamb, Australian, imported, fresh, loin, separable lean and fat, trimmed to 1/8" fat, raw',
#  "DENNY'S, top sirloin steak",
#  'Beef, round, knuckle, tip center, steak, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Frozen yogurts, chocolate, nonfat milk, sweetened without sugar',
#  'Beef, plate steak, boneless, outside skirt, separable lean and fat, trimmed to 0" fat, choice, cooked, grilled',
#  'Puddings, vanilla, dry mix, regular, prepared with 2% milk',
#  "T.G.I. FRIDAY'S, french fries",
#  'Beef, plate steak, boneless, inside skirt, separable lean only, trimmed to 0" fat, all grades, raw',
#  'Fish, salmon, chum, cooked, dry heat',
#  'Fish, sucker, white, raw',
#  'Tamales, masa and pork filling (Hopi)',
#  'Jute, potherb, cooked, boiled, drained, without salt',
#  'Potatoes, hash brown, home-prepared',
#  'Veal, variety meats and by-products, heart, raw',
#  'Veal, shoulder, whole (arm and blade), separable lean only, raw',
#  'Lime juice, raw',
#  "McDONALD'S, Sausage Biscuit",
#  'ON THE BORDER, Mexican rice',
#  'Beef, chuck, mock tender steak, boneless, separable lean only, trimmed to 0" fat, choice, cooked, braised',
#  'Bread, white, commercially prepared (includes soft bread crumbs)',
#  'Soybeans, mature seeds, raw',
#  'Muffins, English, mixed-grain (includes granola)',
#  'Beef, top sirloin, steak, separable lean and fat, trimmed to 0" fat, select, cooked, broiled',
#  'Corn, sweet, yellow, frozen, kernels on cob, cooked, boiled, drained, without salt',
#  'Puddings, chocolate, dry mix, regular, prepared with whole milk',
#  'Beef, rib, back ribs, bone-in, separable lean only, trimmed to 0" fat, select, raw',
#  'Pie, fried pies, cherry',
#  'Beverages, ABBOTT, ENSURE PLUS, ready-to-drink',
#  'Succotash, (corn and limas), raw',
#  'Nuts, beechnuts, dried',
#  'Beef, short loin, top loin, steak, separable lean only, trimmed to 1/8" fat, select, cooked, grilled',
#  'Peppers, sweet, green, cooked, boiled, drained, with salt',
#  'Asparagus, frozen, cooked, boiled, drained, without salt',
#  'Cheese, feta',
#  'Pork, cured, ham with natural juices, whole, boneless, separable lean and fat, unheated',
#  'Melon, banana (Navajo)',
#  'Beet greens, raw',
#  'Fast foods, cheeseburger; double, large patty; with condiments',
#  'Hyacinth beans, mature seeds, cooked, boiled, with salt',
#  'Beef, shoulder top blade steak, boneless, separable lean only, trimmed to 0" fat, choice, cooked, grilled',
#  'Pancakes, plain, frozen, ready-to-heat, microwave (includes buttermilk)',
#  'CRACKER BARREL, grilled sirloin steak',
#  'Fast foods, taco with chicken, lettuce and cheese, soft',
#  'Pork, cured, ham with natural juices, spiral slice, meat only, boneless, separable lean only, heated, roasted',
#  'Potatoes, yellow fleshed, roasted, salt added in processing, frozen, unprepared',
#  'Artificial Blueberry Muffin Mix, dry',
#  'Beef, round, top round steak, boneless, separable lean and fat, trimmed to 0" fat, choice, raw',
#  'Veal, sirloin, separable lean and fat, cooked, braised',
#  'Kohlrabi, raw',
#  'Whey, acid, fluid',
#  'Pork, ground, 72% lean / 28% fat, cooked, crumbles',
#  "Orange juice, raw (Includes foods for USDA's Food Distribution Program)",
#  'Cereals ready-to-eat, ALPEN',
#  'Peppers, sweet, red, cooked, boiled, drained, with salt',
#  'Ice creams, BREYERS, All Natural Light French Chocolate',
#  'Pork, ground, 84% lean / 16% fat, cooked, pan-broiled',
#  'Sour cream, reduced fat',
#  'Beef, variety meats and by-products, heart, raw',
#  'Shortening bread, soybean (hydrogenated) and cottonseed',
#  'Lamb, foreshank, separable lean and fat, trimmed to 1/4" fat, choice, raw',
#  'Snacks, granola bars, soft, uncoated, chocolate chip',
#  'Kohlrabi, cooked, boiled, drained, without salt',
#  'Mustard greens, frozen, unprepared',
#  'Soup, beef broth, less/reduced sodium, ready to serve',
#  'Cowpeas, common (blackeyes, crowder, southern), mature seeds, raw',
#  'Burdock root, cooked, boiled, drained, without salt',
#  'Dip, salsa con queso, cheese and salsa- medium',
#  'KFC, Fried Chicken, EXTRA CRISPY, Wing, meat and skin with breading',
#  'Beef, short loin, t-bone steak, bone-in, separable lean only, trimmed to 1/8" fat, select, cooked, grilled',
#  'Game meat, bison, ground, cooked, pan-broiled',
#  'Salad dressing, russian dressing, low calorie',
#  'Beef, ground, 75% lean meat / 25% fat, loaf, cooked, baked',
#  'Caribou, bone marrow, raw (Alaska Native)',
#  'Alcoholic Beverage, wine, table, red, Carignane',
#  'Nuts, pecans',
#  'Beef, chuck, shoulder clod, top blade, steak, separable lean and fat, trimmed to 0" fat, select, cooked, grilled',
#  'Beef, brisket, flat half, boneless separable lean only, trimmed to 0" fat, all grades, raw',
#  'Beef, rib eye steak/roast, boneless, lip-on, separable lean and fat, trimmed to 1/8" fat, all grades, raw',
#  'Beverages, V8 V-FUSION Juices, Peach Mango',
#  'Cereals ready-to-eat, POST, HONEY BUNCHES OF OATS, pecan bunches',
#  'Raspberries, raw',
#  'Oil, mustard',
#  'Toppings, nuts in syrup',
#  "DENNY'S, chicken strips",
#  'Beef, short loin, top loin, steak, separable lean only, trimmed to 1/8" fat, choice, raw',
#  'Epazote, raw',
#  'Bread, cinnamon',
#  'Beef, chuck, short ribs, boneless, separable lean and fat, trimmed to 0" fat, choice, cooked, braised',
#  'Chicken, broilers or fryers, wing, meat and skin, cooked, fried, batter',
#  'Beef, round, top round, steak, separable lean and fat, trimmed to 1/8" fat, select, raw',
#  'Cheese spread, cream cheese base',
#  'Beef, top sirloin, steak, separable lean and fat, trimmed to 1/8" fat, choice, cooked, pan-fried',
#  'SUBWAY, oven roasted chicken sub on white bread with lettuce and tomato',
#  'Cocoa, dry powder, unsweetened',
#  'Bread, kneel down (Navajo)',
#  'Lamb, New Zealand, imported, square-cut shoulder, separable lean and fat, cooked, slow roasted',
#  'SILK Banana-Strawberry soy yogurt',
#  'DIGIORNO Pizza, pepperoni topping, rising crust, frozen, baked',
#  'Toaster pastries, fruit (includes apple, blueberry, cherry, strawberry)',
#  'Beef, composite of trimmed retail cuts, separable lean and fat, trimmed to 1/8" fat, choice, raw',
#  'Pork, fresh, loin, country-style ribs, separable lean and fat, boneless, cooked, broiled',
#  'Beef, brisket, flat half, separable lean and fat, trimmed to 1/8" fat, all grades, raw',
#  'Eggplant, raw',
#  'Buckwheat flour, whole-groat',
#  'Fish, pompano, florida, cooked, dry heat',
#  'Potatoes, baked, flesh and skin, with salt',
#  'Alcoholic beverage, whiskey sour',
#  'Snacks, M&M MARS, KUDOS Whole Grain Bar, chocolate chip',
#  'Pineapple, raw, extra sweet variety',
#  'Beef, chuck, blade roast, separable lean and fat, trimmed to 1/8" fat, select, cooked, braised',
#  'Beef, ground, 85% lean meat / 15% fat, patty, cooked, broiled',
#  "Cereals, QUAKER, Instant Grits, Ham 'n' Cheese flavor, dry",
#  'TACO BELL, BURRITO SUPREME with chicken',
#  'Broccoli, stalks, raw',
#  'Mushrooms, brown, italian, or crimini, raw',
#  'Turkey, whole, neck, meat only, raw',
#  'Fast foods, sundae, strawberry',
#  'Pork, fresh, composite of trimmed retail cuts (loin and shoulder blade), separable lean and fat, raw',
#  'Caribou, rump meat, half dried (Alaska Native)',
#  'Beef, New Zealand, imported, flat, separable lean and fat, cooked, braised',
#  'Peanuts, all types, dry-roasted, without salt',
#  'Beef, loin, top sirloin petite roast/filet, boneless, separable lean only, trimmed to 0" fat, choice, raw',
#  'Beef, round, bottom round, steak, separable lean and fat, trimmed to 1/8" fat, select, cooked, braised',
#  'Snacks, oriental mix, rice-based',
#  'Beans, french, mature seeds, cooked, boiled, without salt',
#  'Veal, shoulder, blade, separable lean and fat, cooked, braised',
#  'Snacks, granola bar, GENERAL MILLS NATURE VALLEY, SWEET&SALTY NUT, peanut',
#  'Stew, hominy with mutton (Navajo)',
#  'Puff pastry, frozen, ready-to-bake, baked',
#  "Rice, brown, medium-grain, cooked (Includes foods for USDA's Food Distribution Program)",
#  'Beef, bottom sirloin, tri-tip roast, separable lean and fat, trimmed to 0" fat, select, cooked, roasted',
#  'Cheese, brick',
#  'Arrowhead, raw',
#  'Cheese, cheddar, nonfat or fat free',
#  'Beef, loin, top loin, separable lean and fat, trimmed to 1/8" fat, select, cooked, grilled',
#  'Restaurant, family style, onion rings',
#  'Veal, rib, separable lean and fat, cooked, braised',
#  'Salad dressing, caesar, fat-free',
#  'Cheese, mozzarella, low sodium',
#  'Triticale flour, whole-grain',
#  'Taquitos, frozen, beef and cheese, oven-heated',
#  'Millet, cooked',
#  "Corn, sweet, yellow, frozen, kernels cut off cob, unprepared (Includes foods for USDA's Food Distribution Program)",
#  'Lamb, shoulder, whole (arm and blade), separable lean and fat, trimmed to 1/4" fat, choice, cooked, broiled',
#  'Bread, white, commercially prepared, low sodium, no salt',
#  'Apricots, raw',
#  'Beef, chuck, shoulder clod, shoulder top and center steaks, separable lean and fat, trimmed to 0" fat, select, raw',
#  'Beans, black, mature seeds, cooked, boiled, without salt',
#  'Broadbeans (fava beans), mature seeds, raw',
#  'Squash, winter, hubbard, baked, without salt',
#  'Beef, round, bottom round, roast, separable lean only, trimmed to 1/8" fat, choice, raw',
#  'Beverages, OCEAN SPRAY, Cran Cherry',
#  'Pork, fresh, loin, blade (chops or roasts), boneless, separable lean and fat only, raw',
#  'Beverages, dairy drink mix, chocolate, reduced calorie, with aspartame, powder, prepared with water and ice',
#  'Fruit juice smoothie, BOLTHOUSE FARMS, GREEN GOODNESS',
#  "Wheat flour, whole-grain (Includes foods for USDA's Food Distribution Program)",
#  'Frozen novelties, KLONDIKE, SLIM-A-BEAR Fudge Bar, 98% fat free, no sugar added',
#  'Corn, sweet, white, frozen, kernels cut off cob, unprepared',
#  'Lamb, New Zealand, imported, loin, boneless, separable lean and fat, raw',
#  'Cheese, mozzarella, whole milk',
#  'SILK Plus for Bone Health, soymilk',
#  'Game meat, bison, separable lean only, raw',
#  'Potatoes, french fried, cottage-cut, salt not added in processing, frozen, as purchased',
#  'Fast foods, burrito, with beans and beef',
#  'Peaches, dried, sulfured, stewed, with added sugar',
#  'Pretzels, soft, unsalted',
#  'Rolls, hamburger or hot dog, whole wheat',
#  'Beef, rib eye steak, boneless, lip off, separable lean and fat, trimmed to 0" fat, all grades, cooked, grilled',
#  'Beverages, Orange juice, light, No pulp',
#  'Beverages, Wine, non-alcoholic',
#  "Beef, ground, 85% lean meat / 15% fat, raw (Includes foods for USDA's Food Distribution Program)",
#  "Rice, brown, medium-grain, raw (Includes foods for USDA's Food Distribution Program)",
#  'Game meat, elk, tenderloin, separable lean only, cooked, broiled',
#  'Grapefruit juice, white, bottled, unsweetened, OCEAN SPRAY',
#  'Fish, bluefish, raw',
#  'Horned melon (Kiwano)',
#  'Carambola, (starfruit), raw',
#  'Soybeans, green, cooked, boiled, drained, without salt',
#  'Snacks, granola bars, soft, uncoated, chocolate chip, graham and marshmallow',
#  'Ice cream sandwich, made with light ice cream, vanilla',
#  'Beverages, V8 SPLASH Juice Drinks, Orchard Blend',
#  'Seeds, sunflower seed kernels, dried',
#  'Pork, cured, ham with natural juices, slice, boneless, separable lean only, heated, pan-broil',
#  'Oil, nutmeg butter',
#  'Peppermint, fresh',
#  'Nabisco, Nabisco Ritz Crackers',
#  'Beef, chuck for stew, separable lean and fat, all grades, raw',
#  'Lamb, New Zealand, imported, flap, boneless, separable lean and fat, raw',
#  'SILK Chocolate, soymilk',
#  'Beets, cooked, boiled. drained, with salt',
#  'Pizza, cheese topping, rising crust, frozen, cooked',
#  'Oat bran, raw',
#  'Fast foods, miniature cinnamon rolls',
#  'Chicken, broilers or fryers, skin only, cooked, stewed',
#  'Cereals ready-to-eat, SUN COUNTRY, KRETSCHMER Toasted Wheat Bran',
#  'SUBWAY, steak & cheese sub on white bread with American cheese, lettuce and tomato',
#  'Beef, New Zealand, imported, bolar blade, separable lean only, cooked, fast roasted',
#  'Broccoli, frozen, spears, cooked, boiled, drained, without salt',
#  'Orange juice, chilled, includes from concentrate',
#  'Nuts, almonds, oil roasted, with salt added, smoke flavor',
#  'Pasta, fresh-refrigerated, spinach, as purchased',
#  'Pork, fresh, loin, country-style ribs, separable lean only, boneless, cooked, roasted',
#  'TACO BELL, Bean Burrito',
#  'Pomegranate juice, bottled',
#  'Stew/soup, caribou (Alaska Native)',
#  'Cereals, QUAKER, corn grits, instant, plain, dry',
#  'Veal, variety meats and by-products, spleen, raw',
#  'Beef, rib eye steak/roast, bone-in, lip-on, separable lean only, trimmed to 1/8" fat, all grades, raw',
#  "HOT POCKETS Ham 'N Cheese Stuffed Sandwich, frozen",
#  'Formulated bar, high fiber, chewy, oats and chocolate',
#  'Milk, chocolate, fat free, with added vitamin A and vitamin D',
#  'Pudding, lemon, dry mix, regular, prepared with sugar, egg yolk and water',
#  'Peaches, frozen, sliced, sweetened',
#  'MORI-NU, Tofu, silken, lite firm',
#  'Mustard greens, frozen, cooked, boiled, drained, with salt',
#  "Cereals ready-to-eat, QUAKER, CAP'N CRUNCH'S PEANUT BUTTER CRUNCH",
#  'Beef, top loin petite roast/filet, boneless, separable lean and fat, trimmed to 1/8" fat, all grades, raw',
#  'Beef, loin, top loin, separable lean and fat, trimmed to 1/8" fat, select, raw',
#  'Snacks, granola bars, soft, almond, confectioners coating',
#  'Beef, rib eye steak/roast, boneless, lip-on, separable lean and fat, trimmed to 1/8" fat, choice, raw',
#  'Pokeberry shoots, (poke), cooked, boiled, drained, without salt',
#  'Beef, chuck eye Country-Style ribs, boneless, separable lean only, trimmed to 0" fat, select, cooked, braised',
#  'Fish, salmon, chum, raw',
#  'Fish, sheepshead, cooked, dry heat',
#  'Beef, round, top round, separable lean and fat, trimmed to 1/8" fat, all grades, cooked, braised',
#  'Chicken, broilers or fryers, thigh, meat only, cooked, stewed',
#  'Balsam-pear (bitter gourd), pods, raw',
#  'Beef, retail cuts, separable fat, cooked',
#  'Continental Mills, Krusteaz Almond Poppyseed Muffin Mix, Artificially Flavored, dry',
#  'Sausage, pork and beef, fresh, cooked',
#  'Artichokes, (globe or french), frozen, unprepared',
#  'Juice, apple and grape blend, with added ascorbic acid',
#  'Soup, beef barley, ready to serve',
#  'Rice, white, short-grain, raw, unenriched',
#  'Alcoholic beverage, wine, table, white, Muscat',
#  'Ice creams, vanilla, light, no sugar added',
#  'Sweet potato, cooked, baked in skin, flesh, with salt',
#  'Oscar Mayer, Chicken Breast (honey glazed)',
#  'Butter, whipped, with salt',
#  'Toaster pastries, brown-sugar-cinnamon',
#  'Potatoes, yellow fleshed, hash brown, shredded, salt added in processing, frozen, unprepared',
#  'Pork, fresh, loin, blade (chops), bone-in, separable lean only, cooked, broiled',
#  'Beef, round, bottom round, roast, separable lean only, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Alcoholic beverage, whiskey sour, prepared with water, whiskey and powder mix',
#  'Wheat flour, white, bread, enriched',
#  "Cereals ready-to-eat, QUAKER, MOTHER'S GRAHAM BUMPERS",
#  'Game meat, horse, raw',
#  'Snacks, pretzels, hard, whole-wheat including both salted and unsalted',
#  'Fast foods, vanilla, light, soft-serve ice cream, with cone',
#  'Salsify, cooked, boiled, drained, without salt',
#  'Crustaceans, crab, dungeness, cooked, moist heat',
#  'Pork, fresh, loin, whole, separable lean and fat, cooked, broiled',
#  'Sweet Potatoes, french fried, frozen as packaged, salt added in processing',
#  'Nuts, chestnuts, chinese, dried',
#  'Pork, cured, ham -- water added, slice, bone-in, separable lean only, heated, pan-broil',
#  "Pasta, whole-wheat, dry (Includes foods for USDA's Food Distribution Program)",
#  'Beverages, PEPSICO QUAKER, Gatorade, G performance O 2, ready-to-drink.',
#  'Veal, shoulder, whole (arm and blade), separable lean and fat, raw',
#  'Lamb, New Zealand, imported, rack - partly frenched, separable lean only, raw',
#  'Elk, free range, ground, cooked patties (Shoshone Bannock)',
#  'Ice cream sandwich',
#  'Fast foods, cheeseburger, double, regular patty and bun, with condiments',
#  'Cereals ready-to-eat, POST, FRUITY PEBBLES',
#  'Beef, round, top round, steak, separable lean only, trimmed to 1/8" fat, choice, raw',
#  'Lettuce, iceberg (includes crisphead types), raw',
#  'Leavening agents, baking powder, double-acting, sodium aluminum sulfate',
#  'Mung beans, mature seeds, sprouted, raw',
#  'Pork, fresh, shoulder, blade, boston (roasts), separable lean only, cooked, roasted',
#  'Wheat, hard red spring',
#  'Turkey, retail parts, breast, meat only, with added solution, raw',
#  'Cauliflower, raw',
#  'Cheese, swiss, low fat',
#  'Beef, round, tip round, roast, separable lean and fat, trimmed to 1/8" fat, select, cooked, roasted',
#  'Pork, cured, separable fat (from ham and arm picnic), unheated',
#  'Pork, cured, ham, shank, bone-in, separable lean only, heated, roasted',
#  'Beef, plate steak, boneless, inside skirt, separable lean only, trimmed to 0" fat, select, cooked, grilled',
#  'Beans, small white, mature seeds, cooked, boiled, without salt',
#  'Nance, frozen, unsweetened',
#  'Chayote, fruit, raw',
#  'Egg, whole, dried',
#  'Pork, fresh, shoulder, blade, boston (roasts), separable lean and fat, cooked, roasted',
#  'Quail, cooked, total edible',
#  'Jellies, no sugar (with sodium saccharin), any flavors',
#  'Lamb, New Zealand, imported, frozen, composite of trimmed retail cuts, separable lean only, cooked',
#  'Pork, fresh, variety meats and by-products, spleen, cooked, braised',
#  'Beef, round, bottom round, roast, separable lean and fat, trimmed to 1/8" fat, select, cooked, roasted',
#  'Turkey, ground, fat free, pan-broiled crumbles',
#  'Corn, sweet, white, frozen, kernels on cob, unprepared',
#  'Cereals ready-to-eat, POST, HONEY BUNCHES OF OATS with vanilla bunches',
#  'Game meat, deer, tenderloin, separable lean only, cooked, broiled',
#  'Snacks, trail mix, regular, unsalted',
#  'Fish, herring eggs, Pacific, plain (Alaska Native)',
#  'Beef, shoulder pot roast or steak, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  'Lamb, shoulder, blade, separable lean and fat, trimmed to 1/4" fat, choice, cooked, braised',
#  'Beef, chuck eye roast, boneless, America\'s Beef Roast, separable lean and fat, trimmed to 0" fat, all grades, raw',
#  'Beans, navy, mature seeds, cooked, boiled, without salt',
#  'Beef, brisket, flat half, separable lean and fat, trimmed to 1/8" fat, select, raw',
#  'Cabbage, mustard, salted',
#  'Alcoholic beverages, beer, higher alcohol',
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Drumstick, meat only, skin and breading removed',
#  'Beef, chuck, arm pot roast, separable lean and fat, trimmed to 1/8" fat, choice, raw',
#  'Beef, plate steak, boneless, outside skirt, separable lean and fat, trimmed to 0" fat, all grades, cooked, grilled',
#  'Pork, fresh, leg (ham), whole, separable lean only, cooked, roasted',
#  'Rhubarb, wild, leaves (Alaska Native)',
#  'Beef, top loin petite roast/filet, boneless, separable lean only, trimmed to 1/8" fat, choice, raw',
#  'Beverages, carbonated, SPRITE, lemon-lime, without caffeine',
#  'Beef, chuck eye roast, boneless, America\'s Beef Roast, separable lean and fat, trimmed to 0" fat, all grades, cooked, roasted',
#  'Beef, rib, whole (ribs 6-12), separable lean and fat, trimmed to 1/8" fat, choice, raw',
#  'Tart, breakfast, low fat',
#  'Beef, round, bottom round, steak, separable lean and fat, trimmed to 1/8" fat, select, raw',
#  'Bread, rice bran',
#  'Beef, loin, top loin steak, boneless, lip off, separable lean only, trimmed to 0" fat, select, cooked, grilled',
#  'Alcoholic Beverage, wine, table, red, Sangiovese',
#  'Fast foods, croissant, with egg, cheese, and sausage',
#  "McDONALD'S, Sausage McMUFFIN with Egg",
#  'Lamb, New Zealand, imported, loin chop, separable lean and fat, cooked, fast fried',
#  'Oil, peanut, salad or cooking',
#  'Fish, sunfish, pumpkin seed, cooked, dry heat',
#  'Fish, croaker, Atlantic, raw',
#  'Beef, round, tip round, roast, separable lean and fat, trimmed to 0" fat, select, cooked, roasted',
#  "McDONALD'S, Sausage, Egg & Cheese McGRIDDLES",
#  'Raspberries, frozen, red, unsweetened',
#  'Beef, ground, 70% lean meat / 30% fat, patty, cooked, broiled',
#  'Apricots, frozen, sweetened',
#  'Beef, round, top round roast, boneless, separable lean and fat, trimmed to 0" fat, select, raw',
#  'POPEYES, Fried Chicken, Mild, Thigh, meat and skin with breading',
#  'Hazelnuts, beaked (Northern Plains Indians)',
#  'Veal, variety meats and by-products, thymus, raw',
#  'Beef, New Zealand, imported, bolar blade, separable lean only, raw',
#  'Taro, leaves, cooked, steamed, with salt',
#  'Apples, dehydrated (low moisture), sulfured, uncooked',
#  'CRACKER BARREL, steak fries',
#  'Natto',
#  'Oscar Mayer, Smokies Sausage Little Cheese (pork, turkey)',
#  'Game meat, deer, ground, cooked, pan-broiled',
#  'Beef, rib eye steak/roast, boneless, lip-on, separable lean and fat, trimmed to 1/8" fat, select, raw',
#  'Fast foods, griddle cake sandwich, sausage',
#  'Beef, flank, steak, separable lean only, trimmed to 0" fat, choice, cooked, broiled',
#  "Pasta, whole grain, 51% whole wheat, remaining enriched semolina, cooked (Includes foods for USDA's Food Distribution Program)",
#  'Bread, salvadoran sweet cheese (quesadilla salvadorena)',
#  'Puddings, tapioca, dry mix',
#  'Sauce, teriyaki, ready-to-serve, reduced sodium',
#  'Soup, SWANSON, vegetable broth',
#  'Bread, raisin, enriched, toasted',
#  'Chicken, broilers or fryers, meat only, cooked, roasted',
#  'Yogurt, Greek, 2% fat, strawberry banana, CHOBANI',
#  'Beverage, instant breakfast powder, chocolate, not reconstituted',
#  'Pork, fresh, loin, whole, separable lean only, cooked, roasted',
#  'Yogurt, Greek, strawberry, nonfat',
#  'Soy flour, defatted',
#  'Corned beef loaf, jellied',
#  'Puddings, coconut cream, dry mix, regular',
#  'Seal, ringed, liver (Alaska Native)',
#  'Chicken, broilers or fryers, meat only, cooked, stewed',
#  'BURGER KING, Cheeseburger',
#  'Yogurt, Greek, 2% fat, apricot, CHOBANI',
#  'Egg, whole, cooked, scrambled',
#  'Canadian bacon, cooked, pan-fried',
#  'Danish pastry, cheese',
#  'Beef, round, tip round, roast, separable lean only, trimmed to 0" fat, all grades, raw',
#  'Spinach, frozen, chopped or leaf, cooked, boiled, drained, without salt',
#  'Amaranth grain, uncooked',
#  'Beef, top loin petite roast/filet, boneless, separable lean only, trimmed to 1/8" fat, all grades, raw',
#  'Puddings, chocolate, dry mix, instant, prepared with whole milk',
#  'Peanut butter, reduced sodium',
#  'Pork, fresh, variety meats and by-products, lungs, raw',
#  'Pectin, liquid',
#  'Turkey, whole, meat and skin, raw',
#  'Pork sausage, link/patty, reduced fat, cooked, pan-fried',
#  'Game meat, muskrat, raw',
#  'Danish pastry, cinnamon, enriched',
#  'Beef, rib eye roast, bone-in, lip-on, separable lean and fat, trimmed to 1/8" fat, choice, cooked, roasted',
#  'Gourd, white-flowered (calabash), cooked, boiled, drained, with salt',
#  'Broadbeans (fava beans), mature seeds, cooked, boiled, with salt',
#  'Lima beans, immature seeds, frozen, baby, unprepared',
#  'Milk, evaporated, 2% fat, with added vitamin A and vitamin D',
#  'Persimmons, japanese, raw',
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Drumstick, meat and skin with breading',
#  'Pork, fresh, leg (ham), rump half, separable lean only, cooked, roasted',
#  'SILK Plus Fiber, soymilk',
#  'Shortening confectionery, coconut (hydrogenated) and or palm kernel (hydrogenated)',
#  'Beef, chuck, blade roast, separable lean and fat, trimmed to 1/8" fat, choice, cooked, braised',
#  'Pork, cured, ham and water product, slice, bone-in, separable lean and fat, unheated',
#  'Puddings, tapioca, ready-to-eat',
#  'Potatoes, french fried, steak fries, salt added in processing, frozen, oven-heated',
#  'Ham, honey, smoked, cooked',
#  'Egg, white, raw, frozen, pasteurized',
#  'Chicken, stewing, light meat, meat only, cooked, stewed',
#  'Beverages, V8 SPLASH Juice Drinks, Orange Pineapple',
#  'Water convolvulus,raw',
#  'Cowpeas, leafy tips, raw',
#  'Turnips, cooked, boiled, drained, with salt',
#  'Beef, round, full cut, separable lean and fat, trimmed to 1/8" fat, choice, raw',
#  'Beef, brisket, flat half, separable lean only, trimmed to 1/8" fat, select, raw',
#  'Carissa, (natal-plum), raw',
#  'Cereals, corn grits, white, regular and quick, enriched, cooked with water, with salt',
#  'Beef, loin, top loin steak, boneless, lip-on, separable lean and fat, trimmed to 1/8" fat, choice, cooked, grilled',
#  'Beef, chuck eye roast, boneless, America\'s Beef Roast, separable lean only, trimmed to 0" fat, choice, raw',
#  'Veal, variety meats and by-products, thymus, cooked, braised',
#  'Pork, cured, ham -- water added, slice, bone-in, separable lean only, unheated',
#  'Beef, New Zealand, imported, striploin, separable lean and fat, raw',
#  'Beef, Australian, imported, grass-fed, loin, top loin steak/roast, boneless, separable lean and fat, raw',
#  'Crustaceans, spiny lobster, mixed species, cooked, moist heat',
#  'Salad dressing, italian dressing, commercial, regular, without salt',
#  'Beef, New Zealand, imported, brisket point end, separable lean only, raw',
#  'Fish, pollock, Alaska, raw',
#  'Pork, fresh, loin, country-style ribs, separable lean and fat, bone-in, cooked, roasted',
#  'Pork, fresh, variety meats and by-products, feet, cooked, simmered',
#  'Fish, salmon, coho, farmed, raw',
#  'Squash, winter, acorn, cooked, baked, without salt',
#  'Pork, cured, ham, rump, bone-in, separable lean and fat, heated, roasted',
#  'Chicken, broiler, rotisserie, BBQ, thigh, meat only',
#  'Ice creams, BREYERS, All Natural Light Vanilla',
#  'Egg, yolk, raw, fresh',
#  'Seasoning mix, dry, chili, original',
#  ...]

# %%
# find nutrient that miss Energy
nutrients_missing_energy = []
for food in nutrients:
    if 'Fiber, total dietary' in nutrients[food]:
        pass
    else:
        print('There is no energy in ', food)
        print(nutrients[food])
        nutrients_missing_energy.append(food)
nutrients_missing_energy
# Out:
# There is no energy in  Chilchen (Red Berry Beverage) (Navajo)
# {'Total lipid (fat)': 0.63, 'Carbohydrate, by difference': 8.68, 'Energy': 43.738098, 'Sugars, total including NLEA': 2.6, 'Calcium, Ca': 7.0, 'Potassium, K': 28.0, 'Zinc, Zn': 0.19, 'Vitamin E (alpha-tocopherol)': 0.0, 'Niacin': 0.248, 'Vitamin B-6': 0.033, 'Iron, Fe': 0.95, 'Magnesium, Mg': 9.0, 'Phosphorus, P': 23.0, 'Sodium, Na': 15.0, 'Copper, Cu': 0.019, 'Thiamin': 0.02, 'Riboflavin': 0.015, 'Vitamin K (phylloquinone)': 0.0, 'Fatty acids, total saturated': 0.075, 'Protein': 0.81}
# There is no energy in  Alcoholic beverage, wine, table, white, Gewurztraminer
# {'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 2.6, 'Protein': 0.07, 'Energy': 80.545022}
# There is no energy in  Winged bean tuber, raw
# {'Energy': 148, 'Folic acid': 0.0, 'Folate, DFE': 19.0, 'Vitamin A, RAE': 0.0, 'Fatty acids, total saturated': 0.222, 'Cholesterol': 0.0, 'Protein': 11.6, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.379, 'Riboflavin': 0.149, 'Vitamin B-12': 0.0, 'Iron, Fe': 2.0, 'Magnesium, Mg': 24.0, 'Phosphorus, P': 45.0, 'Sodium, Na': 35.0, 'Copper, Cu': 1.39, 'Calcium, Ca': 30.0, 'Potassium, K': 586, 'Zinc, Zn': 1.39, 'Niacin': 1.64, 'Vitamin B-6': 0.075, 'Total lipid (fat)': 0.9, 'Carbohydrate, by difference': 28.1, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.7}
# There is no energy in  Purslane, cooked, boiled, drained, with salt
# {'Folic acid': 0.0, 'Energy': 18.0, 'Carbohydrate, by difference': 3.55, 'Vitamin A, RAE': 93.0, 'Folate, DFE': 9.0, 'Vitamin C, total ascorbic acid': 10.5, 'Thiamin': 0.031, 'Riboflavin': 0.09, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Protein': 1.49, 'Iron, Fe': 0.77, 'Magnesium, Mg': 67.0, 'Phosphorus, P': 37.0, 'Sodium, Na': 280, 'Copper, Cu': 0.114, 'Total lipid (fat)': 0.19, 'Calcium, Ca': 78.0, 'Potassium, K': 488, 'Zinc, Zn': 0.17, 'Niacin': 0.46, 'Vitamin B-6': 0.07, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.9}
# There is no energy in  Veal, breast, whole, boneless, separable lean and fat, cooked, braised
# {'Energy': 266, 'Folic acid': 0.0, 'Selenium, Se': 11.0, 'Folate, DFE': 13.0, 'Protein': 27.0, 'Iron, Fe': 0.77, 'Magnesium, Mg': 20.0, 'Phosphorus, P': 191, 'Sodium, Na': 65.0, 'Copper, Cu': 0.071, 'Thiamin': 0.054, 'Riboflavin': 0.296, 'Vitamin B-12': 1.33, 'Cholesterol': 113, 'Fatty acids, total saturated': 6.55, 'Niacin': 7.98, 'Vitamin B-6': 0.261, 'Total lipid (fat)': 16.8, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 9.0, 'Potassium, K': 272, 'Zinc, Zn': 3.64}
# There is no energy in  Lentils, sprouted, raw
# {'Energy': 106, 'Folic acid': 0.0, 'Folate, DFE': 100, 'Vitamin A, RAE': 2.0, 'Total lipid (fat)': 0.55, 'Carbohydrate, by difference': 22.1, 'Calcium, Ca': 25.0, 'Potassium, K': 322, 'Zinc, Zn': 1.51, 'Niacin': 1.13, 'Vitamin B-6': 0.19, 'Protein': 8.96, 'Iron, Fe': 3.21, 'Magnesium, Mg': 37.0, 'Phosphorus, P': 173, 'Sodium, Na': 11.0, 'Copper, Cu': 0.352, 'Vitamin C, total ascorbic acid': 16.5, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.057, 'Thiamin': 0.228, 'Riboflavin': 0.128, 'Vitamin B-12': 0.0, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.6}
# There is no energy in  Mashu roots, raw (Alaska Native)
# {'Protein': 5.8, 'Energy': 135, 'Phosphorus, P': 67.0, 'Vitamin C, total ascorbic acid': 11.0, 'Thiamin': 0.1, 'Riboflavin': 0.07, 'Total lipid (fat)': 2.4, 'Carbohydrate, by difference': 22.6, 'Niacin': 1.3}
# There is no energy in  Chicken, broilers or fryers, dark meat, meat and skin, cooked, fried, batter
# {'Energy': 298, 'Folate, DFE': 24.0, 'Selenium, Se': 23.6, 'Folic acid': 9.0, 'Vitamin A, RAE': 31.0, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.117, 'Riboflavin': 0.218, 'Vitamin B-12': 0.27, 'Protein': 21.8, 'Iron, Fe': 1.44, 'Magnesium, Mg': 20.0, 'Phosphorus, P': 145, 'Sodium, Na': 295, 'Copper, Cu': 0.08, 'Cholesterol': 89.0, 'Fatty acids, total saturated': 4.95, 'Niacin': 5.61, 'Vitamin B-6': 0.25, 'Total lipid (fat)': 18.6, 'Carbohydrate, by difference': 9.38, 'Calcium, Ca': 21.0, 'Potassium, K': 185, 'Zinc, Zn': 2.08}
# There is no energy in  Pancakes, blueberry, prepared from recipe
# {'Energy': 222, 'Folate, DFE': 53.0, 'Folic acid': 24.0, 'Vitamin A, RAE': 50.0, 'Total lipid (fat)': 9.2, 'Carbohydrate, by difference': 29.0, 'Calcium, Ca': 206, 'Potassium, K': 138, 'Zinc, Zn': 0.54, 'Niacin': 1.52, 'Vitamin B-6': 0.049, 'Vitamin B-12': 0.2, 'Vitamin C, total ascorbic acid': 2.2, 'Thiamin': 0.195, 'Riboflavin': 0.272, 'Iron, Fe': 1.72, 'Magnesium, Mg': 16.0, 'Phosphorus, P': 151, 'Sodium, Na': 412, 'Copper, Cu': 0.055, 'Protein': 6.1, 'Cholesterol': 56.0, 'Fatty acids, total saturated': 1.99, 'Selenium, Se': 14.0}
# There is no energy in  Nuts, chestnuts, chinese, boiled and steamed
# {'Folic acid': 0.0, 'Vitamin D (D2 + D3)': 0.0, 'Vitamin A, RAE': 7.0, 'Energy': 153, 'Folate, DFE': 46.0, 'Total lipid (fat)': 0.76, 'Carbohydrate, by difference': 33.6, 'Calcium, Ca': 12.0, 'Potassium, K': 306, 'Zinc, Zn': 0.6, 'Niacin': 0.548, 'Vitamin B-6': 0.281, 'Protein': 2.88, 'Iron, Fe': 0.97, 'Magnesium, Mg': 58.0, 'Phosphorus, P': 66.0, 'Sodium, Na': 2.0, 'Copper, Cu': 0.249, 'Vitamin C, total ascorbic acid': 24.7, 'Thiamin': 0.11, 'Riboflavin': 0.123, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.112}
# There is no energy in  CAMPBELL'S, Chicken Noodle Soup, condensed
# {'Total lipid (fat)': 1.53, 'Carbohydrate, by difference': 5.97, 'Energy': 47.084182, 'Sugars, total including NLEA': 0.0, 'Calcium, Ca': 6.0, 'Potassium, K': 44.0, 'Zinc, Zn': 0.28, 'Fatty acids, total saturated': 0.388, 'Protein': 2.37, 'Iron, Fe': 0.69, 'Magnesium, Mg': 8.0, 'Phosphorus, P': 38.0, 'Sodium, Na': 683, 'Copper, Cu': 0.027, 'Cholesterol': 8.0}
# There is no energy in  Grapefruit, raw, white, Florida
# {'Energy': 32.0, 'Folic acid': 0.0, 'Protein': 0.63, 'Fatty acids, total saturated': 0.014, 'Iron, Fe': 0.05, 'Magnesium, Mg': 9.0, 'Phosphorus, P': 7.0, 'Sodium, Na': 0.0, 'Copper, Cu': 0.056, 'Vitamin C, total ascorbic acid': 37.0, 'Thiamin': 0.04, 'Riboflavin': 0.02, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Total lipid (fat)': 0.1, 'Carbohydrate, by difference': 8.19, 'Calcium, Ca': 15.0, 'Potassium, K': 150, 'Zinc, Zn': 0.07, 'Niacin': 0.2, 'Vitamin B-6': 0.043, 'Folate, DFE': 9.0, 'Vitamin A, RAE': 0.0, 'Vitamin D (D2 + D3)': 0.0}
# There is no energy in  Pate, truffle flavor
# {'Protein': 11.2, 'Iron, Fe': 3.94, 'Sodium, Na': 807, 'Carotene, beta': 0.0, 'Cholesterol': 105, 'Fatty acids, total saturated': 10.1, 'Total lipid (fat)': 28.5, 'Carbohydrate, by difference': 6.3, 'Energy': 327.43822, 'Calcium, Ca': 70.0, 'Potassium, K': 138, 'Zinc, Zn': 2.85, 'Selenium, Se': 41.6, 'Niacin': 3.3, 'Vitamin B-6': 0.06, 'Folic acid': 0.0, 'Vitamin A, RAE': 4500.0, 'Vitamin C, total ascorbic acid': 2.0, 'Thiamin': 0.03, 'Riboflavin': 0.6, 'Vitamin B-12': 3.2, 'Copper, Cu': 0.4, 'Magnesium, Mg': 13.0, 'Phosphorus, P': 200, 'Folate, DFE': 60.0}
# There is no energy in  Lamb, Australian, imported, fresh, leg, sirloin chops, boneless, separable lean and fat, trimmed to 1/8" fat, cooked, broiled
# {'Energy': 235, 'Carbohydrate, by difference': 0.0, 'Total lipid (fat)': 13.8, 'Calcium, Ca': 14.0, 'Potassium, K': 336, 'Zinc, Zn': 4.83, 'Niacin': 5.43, 'Vitamin B-6': 0.43, 'Protein': 25.8, 'Phosphorus, P': 224, 'Sodium, Na': 64.0, 'Copper, Cu': 0.162, 'Thiamin': 0.128, 'Riboflavin': 0.391, 'Vitamin B-12': 3.05, 'Cholesterol': 85.0, 'Fatty acids, total saturated': 6.41, 'Iron, Fe': 2.34, 'Magnesium, Mg': 25.0, 'Selenium, Se': 10.1}
# There is no energy in  Duck, young duckling, domesticated, White Pekin, breast, meat and skin, boneless, cooked, roasted
# {'Energy': 202, 'Selenium, Se': 26.4, 'Protein': 24.5, 'Iron, Fe': 3.26, 'Sodium, Na': 84.0, 'Vitamin C, total ascorbic acid': 2.8, 'Cholesterol': 136, 'Fatty acids, total saturated': 2.92, 'Total lipid (fat)': 10.8, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 8.0, 'Niacin': 7.86}
# There is no energy in  Alcoholic beverage, wine, table, white, Fume Blanc
# {'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 2.27, 'Protein': 0.07, 'Energy': 82.0}
# There is no energy in  POPEYES, Fried Chicken, Mild, Drumstick, meat and skin with breading
# {'Calcium, Ca': 20.0, 'Potassium, K': 261, 'Zinc, Zn': 1.76, 'Selenium, Se': 27.9, 'Niacin': 5.44, 'Vitamin B-6': 0.235, 'Cholesterol': 108, 'Thiamin': 0.101, 'Riboflavin': 0.25, 'Vitamin B-12': 0.62, 'Iron, Fe': 1.06, 'Magnesium, Mg': 22.0, 'Phosphorus, P': 171, 'Sodium, Na': 588, 'Copper, Cu': 0.074, 'Total lipid (fat)': 19.1, 'Carbohydrate, by difference': 9.84, 'Energy': 293.97738, 'Protein': 20.4, 'Fatty acids, total saturated': 6.59}
# There is no energy in  POPEYES, Fried Chicken, Mild, Breast, meat only, skin and breading removed
# {'Total lipid (fat)': 4.52, 'Carbohydrate, by difference': 0.0, 'Energy': 156.54892999999998, 'Calcium, Ca': 20.0, 'Potassium, K': 327, 'Zinc, Zn': 0.97, 'Selenium, Se': 35.2, 'Vitamin E (alpha-tocopherol)': 0.21, 'Niacin': 9.39, 'Vitamin B-6': 0.37, 'Choline, total': 99.7, 'Protein': 29.0, 'Iron, Fe': 0.55, 'Magnesium, Mg': 29.0, 'Phosphorus, P': 219, 'Sodium, Na': 526, 'Copper, Cu': 0.052, 'Vitamin A, RAE': 4.0, 'Thiamin': 0.107, 'Riboflavin': 0.24, 'Vitamin B-12': 0.33, 'Cholesterol': 97.0, 'Fatty acids, total saturated': 1.37}
# There is no energy in  Buffalo, free range, top round steak, raw (Shoshone Bannock)
# {'Protein': 21.4, 'Iron, Fe': 2.61, 'Magnesium, Mg': 22.0, 'Phosphorus, P': 200, 'Sodium, Na': 43.0, 'Copper, Cu': 0.117, 'Thiamin': 0.153, 'Riboflavin': 0.325, 'Vitamin B-12': 1.15, 'Fatty acids, total saturated': 0.418, 'Total lipid (fat)': 1.3, 'Calcium, Ca': 3.0, 'Potassium, K': 355, 'Zinc, Zn': 3.0, 'Selenium, Se': 7.0, 'Niacin': 6.92, 'Vitamin B-6': 0.78, 'Energy': 97.0, 'Carbohydrate, by difference': 0.0}
# There is no energy in  Triticale
# {'Folic acid': 0.0, 'Vitamin A, RAE': 0.0, 'Energy': 336, 'Folate, DFE': 73.0, 'Niacin': 1.43, 'Vitamin B-6': 0.138, 'Total lipid (fat)': 2.09, 'Carbohydrate, by difference': 72.1, 'Calcium, Ca': 37.0, 'Potassium, K': 332, 'Zinc, Zn': 3.45, 'Vitamin E (alpha-tocopherol)': 0.9, 'Protein': 13.0, 'Iron, Fe': 2.57, 'Magnesium, Mg': 130, 'Phosphorus, P': 358, 'Sodium, Na': 5.0, 'Copper, Cu': 0.457, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.416, 'Riboflavin': 0.134, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.366, 'Vitamin D (D2 + D3)': 0.0}
# There is no energy in  Lamb, Australian, imported, fresh, leg, sirloin chops, boneless, separable lean only, trimmed to 1/8" fat, raw
# {'Energy': 132, 'Selenium, Se': 8.0, 'Carbohydrate, by difference': 0.0, 'Protein': 20.4, 'Iron, Fe': 1.94, 'Magnesium, Mg': 25.0, 'Phosphorus, P': 214, 'Sodium, Na': 64.0, 'Copper, Cu': 0.156, 'Thiamin': 0.155, 'Riboflavin': 0.32, 'Vitamin B-12': 3.01, 'Cholesterol': 64.0, 'Fatty acids, total saturated': 1.95, 'Niacin': 5.56, 'Vitamin B-6': 0.406, 'Calcium, Ca': 9.0, 'Potassium, K': 342, 'Zinc, Zn': 3.58, 'Total lipid (fat)': 4.91}
# There is no energy in  Squash, winter, butternut, frozen, cooked, boiled, without salt
# {'Energy': 39.0, 'Folic acid': 0.0, 'Folate, DFE': 16.0, 'Vitamin A, RAE': 167, 'Protein': 1.23, 'Iron, Fe': 0.58, 'Magnesium, Mg': 9.0, 'Phosphorus, P': 14.0, 'Sodium, Na': 2.0, 'Copper, Cu': 0.036, 'Fatty acids, total saturated': 0.014, 'Cholesterol': 0.0, 'Vitamin C, total ascorbic acid': 3.5, 'Thiamin': 0.05, 'Riboflavin': 0.039, 'Vitamin B-12': 0.0, 'Total lipid (fat)': 0.07, 'Carbohydrate, by difference': 10.0, 'Calcium, Ca': 19.0, 'Potassium, K': 133, 'Zinc, Zn': 0.12, 'Niacin': 0.464, 'Vitamin B-6': 0.069, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.5}
# There is no energy in  Muffins, blueberry, prepared from recipe, made with low fat (2%) milk
# {'Energy': 285, 'Folate, DFE': 73.0, 'Folic acid': 36.0, 'Vitamin A, RAE': 38.0, 'Vitamin C, total ascorbic acid': 1.5, 'Thiamin': 0.272, 'Riboflavin': 0.289, 'Protein': 6.5, 'Iron, Fe': 2.27, 'Magnesium, Mg': 16.0, 'Phosphorus, P': 145, 'Sodium, Na': 441, 'Copper, Cu': 0.071, 'Vitamin B-12': 0.14, 'Cholesterol': 37.0, 'Fatty acids, total saturated': 2.03, 'Total lipid (fat)': 10.8, 'Carbohydrate, by difference': 40.7, 'Calcium, Ca': 189, 'Potassium, K': 123, 'Zinc, Zn': 0.54, 'Niacin': 2.21, 'Vitamin B-6': 0.043, 'Selenium, Se': 17.1}
# There is no energy in  Peas, mature seeds, sprouted, cooked, boiled, drained, with salt
# {'Folic acid': 0.0, 'Folate, DFE': 36.0, 'Vitamin A, RAE': 5.0, 'Carbohydrate, by difference': 17.1, 'Energy': 98.231466, 'Protein': 7.05, 'Iron, Fe': 1.67, 'Magnesium, Mg': 41.0, 'Phosphorus, P': 24.0, 'Sodium, Na': 239, 'Copper, Cu': 0.02, 'Fatty acids, total saturated': 0.09, 'Vitamin C, total ascorbic acid': 6.6, 'Thiamin': 0.216, 'Riboflavin': 0.285, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Total lipid (fat)': 0.51, 'Calcium, Ca': 26.0, 'Potassium, K': 268, 'Zinc, Zn': 0.78, 'Niacin': 1.07, 'Vitamin B-6': 0.128, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.6}
# There is no energy in  Apple juice, frozen concentrate, unsweetened, undiluted, with added ascorbic acid
# {'Folic acid': 0.0, 'Folate, DFE': 1.0, 'Sugars, total including NLEA': 38.8, 'Vitamin A, RAE': 0.0, 'Energy': 166, 'Fatty acids, total saturated': 0.06, 'Cholesterol': 0.0, 'Vitamin C, total ascorbic acid': 88.9, 'Thiamin': 0.011, 'Riboflavin': 0.054, 'Vitamin B-12': 0.0, 'Iron, Fe': 0.91, 'Magnesium, Mg': 17.0, 'Phosphorus, P': 25.0, 'Sodium, Na': 25.0, 'Copper, Cu': 0.05, 'Protein': 0.51, 'Calcium, Ca': 20.0, 'Potassium, K': 448, 'Zinc, Zn': 0.13, 'Niacin': 0.135, 'Vitamin B-6': 0.116, 'Total lipid (fat)': 0.37, 'Carbohydrate, by difference': 41.0, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.4}
# There is no energy in  Bear, polar, meat, raw (Alaska Native)
# {'Protein': 25.6, 'Energy': 130, 'Iron, Fe': 6.1, 'Vitamin C, total ascorbic acid': 2.0, 'Thiamin': 0.023, 'Riboflavin': 0.573, 'Fatty acids, total saturated': 0.63, 'Total lipid (fat)': 3.1, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 17.0, 'Potassium, K': 40.0, 'Niacin': 4.0}
# There is no energy in  Beverages, V8 SPLASH Juice Drinks, Guava Passion Fruit
# {'Protein': 0.0, 'Energy': 33.0, 'Sodium, Na': 14.0, 'Vitamin C, total ascorbic acid': 24.7, 'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 7.82, 'Sugars, total including NLEA': 7.82, 'Potassium, K': 12.0, 'Vitamin E (alpha-tocopherol)': 1.11}
# There is no energy in  Lamb, New Zealand, imported, tunnel-boned leg, chump off, shank off, separable lean and fat, raw
# {'Total lipid (fat)': 4.09, 'Carbohydrate, by difference': 0.0, 'Energy': 120.459024, 'Calcium, Ca': 4.0, 'Potassium, K': 344, 'Zinc, Zn': 3.26, 'Selenium, Se': 3.6, 'Vitamin E (alpha-tocopherol)': 0.3, 'Niacin': 5.23, 'Vitamin B-6': 0.225, 'Protein': 20.9, 'Iron, Fe': 1.4, 'Magnesium, Mg': 24.0, 'Phosphorus, P': 197, 'Sodium, Na': 60.0, 'Copper, Cu': 0.123, 'Vitamin A, RAE': 3.0, 'Vitamin D (D2 + D3)': 0.0, 'Thiamin': 0.14, 'Riboflavin': 0.201, 'Vitamin B-12': 1.89, 'Cholesterol': 64.0, 'Fatty acids, total saturated': 1.37}
# There is no energy in  Chiton, leathery, gumboots (Alaska Native)
# {'Protein': 17.1, 'Energy': 83.0, 'Iron, Fe': 16.0, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.05, 'Riboflavin': 0.34, 'Total lipid (fat)': 1.6, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 121, 'Niacin': 4.2}
# There is no energy in  Alcoholic beverage, wine, table, white, Sauvignon Blanc
# {'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 2.05, 'Protein': 0.07, 'Energy': 81.0}
# There is no energy in  Rose-apples, raw
# {'Energy': 25.0, 'Vitamin A, RAE': 17.0, 'Protein': 0.6, 'Iron, Fe': 0.07, 'Magnesium, Mg': 5.0, 'Phosphorus, P': 8.0, 'Sodium, Na': 0.0, 'Copper, Cu': 0.016, 'Vitamin C, total ascorbic acid': 22.3, 'Thiamin': 0.02, 'Riboflavin': 0.03, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Total lipid (fat)': 0.3, 'Carbohydrate, by difference': 5.7, 'Calcium, Ca': 29.0, 'Potassium, K': 123, 'Zinc, Zn': 0.06, 'Niacin': 0.8}
# There is no energy in  KFC, Fried Chicken, ORIGINAL RECIPE, Breast, meat only, skin and breading removed
# {'Total lipid (fat)': 4.56, 'Carbohydrate, by difference': 0.0, 'Energy': 148.661732, 'Calcium, Ca': 25.0, 'Potassium, K': 285, 'Zinc, Zn': 0.97, 'Selenium, Se': 33.1, 'Vitamin E (alpha-tocopherol)': 0.33, 'Niacin': 8.67, 'Vitamin B-6': 0.28, 'Choline, total': 93.4, 'Protein': 26.9, 'Iron, Fe': 0.53, 'Magnesium, Mg': 27.0, 'Phosphorus, P': 255, 'Sodium, Na': 499, 'Copper, Cu': 0.063, 'Vitamin A, RAE': 5.0, 'Thiamin': 0.102, 'Riboflavin': 0.223, 'Vitamin B-12': 0.26, 'Cholesterol': 96.0, 'Fatty acids, total saturated': 1.03}
# There is no energy in  Lamb, Australian, imported, fresh, leg, sirloin chops, boneless, separable lean and fat, trimmed to 1/8" fat, raw
# {'Energy': 208, 'Selenium, Se': 7.1, 'Carbohydrate, by difference': 0.0, 'Protein': 18.3, 'Iron, Fe': 1.75, 'Magnesium, Mg': 22.0, 'Phosphorus, P': 192, 'Sodium, Na': 59.0, 'Copper, Cu': 0.139, 'Thiamin': 0.14, 'Riboflavin': 0.288, 'Vitamin B-12': 2.72, 'Cholesterol': 66.0, 'Fatty acids, total saturated': 6.9, 'Total lipid (fat)': 14.4, 'Calcium, Ca': 11.0, 'Potassium, K': 308, 'Zinc, Zn': 3.21, 'Niacin': 5.0, 'Vitamin B-6': 0.362}
# There is no energy in  Lamb, Australian, imported, fresh, loin, separable lean only, trimmed to 1/8" fat, cooked, broiled
# {'Energy': 192, 'Selenium, Se': 10.3, 'Total lipid (fat)': 8.75, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 21.0, 'Potassium, K': 340, 'Zinc, Zn': 3.48, 'Niacin': 8.15, 'Vitamin B-6': 0.514, 'Iron, Fe': 2.18, 'Magnesium, Mg': 26.0, 'Phosphorus, P': 220, 'Sodium, Na': 80.0, 'Copper, Cu': 0.156, 'Thiamin': 0.18, 'Riboflavin': 0.333, 'Vitamin B-12': 2.01, 'Cholesterol': 81.0, 'Fatty acids, total saturated': 3.69, 'Protein': 26.5}
# There is no energy in  Lamb, Australian, imported, fresh, leg, center slice, bone-in, separable lean and fat, trimmed to 1/8" fat, cooked, broiled
# {'Energy': 215, 'Selenium, Se': 13.5, 'Carbohydrate, by difference': 0.0, 'Vitamin B-12': 3.1, 'Fatty acids, total saturated': 5.32, 'Total lipid (fat)': 11.8, 'Calcium, Ca': 14.0, 'Potassium, K': 342, 'Zinc, Zn': 4.95, 'Niacin': 5.53, 'Vitamin B-6': 0.44, 'Protein': 25.5, 'Iron, Fe': 2.38, 'Magnesium, Mg': 25.0, 'Phosphorus, P': 228, 'Sodium, Na': 65.0, 'Copper, Cu': 0.165, 'Thiamin': 0.13, 'Riboflavin': 0.4, 'Cholesterol': 85.0}
# There is no energy in  Bacon, turkey, unprepared
# {'Carotene, beta': 0.0, 'Carotene, alpha': 0.0, 'Lycopene': 0.0, 'Lutein + zeaxanthin': 0.0, 'Iron, Fe': 1.4, 'Magnesium, Mg': 16.0, 'Phosphorus, P': 222, 'Sodium, Na': 1070.0, 'Copper, Cu': 0.068, 'Vitamin A, RAE': 10.0, 'Thiamin': 0.03, 'Riboflavin': 0.237, 'Vitamin B-12': 1.19, 'Cholesterol': 86.0, 'Fatty acids, total saturated': 4.52, 'Protein': 15.9, 'Niacin': 4.03, 'Vitamin B-6': 0.244, 'Total lipid (fat)': 16.9, 'Calcium, Ca': 80.0, 'Potassium, K': 349, 'Zinc, Zn': 2.54, 'Selenium, Se': 15.8, 'Vitamin E (alpha-tocopherol)': 0.11, 'Carbohydrate, by difference': 1.89, 'Energy': 225.621664}
# There is no energy in  Nuts, pilinuts, dried
# {'Folic acid': 0.0, 'Vitamin A, RAE': 2.0, 'Energy': 719, 'Folate, DFE': 60.0, 'Iron, Fe': 3.53, 'Magnesium, Mg': 302, 'Phosphorus, P': 575, 'Sodium, Na': 3.0, 'Copper, Cu': 0.958, 'Vitamin C, total ascorbic acid': 0.6, 'Thiamin': 0.913, 'Riboflavin': 0.093, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 31.2, 'Protein': 10.8, 'Total lipid (fat)': 79.6, 'Carbohydrate, by difference': 3.98, 'Calcium, Ca': 145, 'Potassium, K': 507, 'Zinc, Zn': 2.97, 'Niacin': 0.519, 'Vitamin B-6': 0.115}
# There is no energy in  Pasta, fresh-refrigerated, spinach, as purchased
# {'Energy': 289, 'Folate, DFE': 262, 'Folic acid': 121, 'Vitamin A, RAE': 25.0, 'Total lipid (fat)': 2.1, 'Carbohydrate, by difference': 55.7, 'Calcium, Ca': 43.0, 'Potassium, K': 272, 'Zinc, Zn': 1.4, 'Niacin': 3.46, 'Vitamin B-6': 0.315, 'Cholesterol': 73.0, 'Fatty acids, total saturated': 0.483, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.609, 'Riboflavin': 0.398, 'Vitamin B-12': 0.31, 'Protein': 11.3, 'Iron, Fe': 3.3, 'Magnesium, Mg': 63.0, 'Phosphorus, P': 148, 'Sodium, Na': 27.0, 'Copper, Cu': 0.197}
# There is no energy in  Nuts, ginkgo nuts, dried
# {'Energy': 348, 'Folic acid': 0.0, 'Folate, DFE': 106, 'Vitamin D (D2 + D3)': 0.0, 'Vitamin A, RAE': 55.0, 'Total lipid (fat)': 2.0, 'Carbohydrate, by difference': 72.4, 'Calcium, Ca': 20.0, 'Potassium, K': 998, 'Zinc, Zn': 0.67, 'Niacin': 11.7, 'Vitamin B-6': 0.641, 'Protein': 10.4, 'Iron, Fe': 1.6, 'Magnesium, Mg': 53.0, 'Phosphorus, P': 269, 'Sodium, Na': 13.0, 'Copper, Cu': 0.536, 'Vitamin C, total ascorbic acid': 29.3, 'Thiamin': 0.43, 'Riboflavin': 0.176, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.381}
# There is no energy in  Pie crust, standard-type, dry mix
# {'Energy': 518, 'Folate, DFE': 164, 'Folic acid': 86.0, 'Vitamin A, RAE': 0.0, 'Iron, Fe': 2.22, 'Magnesium, Mg': 15.0, 'Phosphorus, P': 86.0, 'Sodium, Na': 753, 'Copper, Cu': 0.075, 'Protein': 6.9, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.392, 'Riboflavin': 0.213, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Total lipid (fat)': 31.4, 'Carbohydrate, by difference': 52.1, 'Calcium, Ca': 61.0, 'Potassium, K': 64.0, 'Zinc, Zn': 0.4, 'Niacin': 2.73, 'Vitamin B-6': 0.064, 'Fatty acids, total saturated': 7.97, 'Selenium, Se': 22.9}
# There is no energy in  Restaurant, family style, sirloin steak
# {'Protein': 29.8, 'Energy': 195, 'Iron, Fe': 2.57, 'Magnesium, Mg': 27.0, 'Phosphorus, P': 230, 'Sodium, Na': 339, 'Copper, Cu': 0.1, 'Vitamin A, RAE': 8.0, 'Thiamin': 0.077, 'Riboflavin': 0.347, 'Vitamin B-12': 2.54, 'Cholesterol': 87.0, 'Fatty acids, total saturated': 3.14, 'Total lipid (fat)': 8.48, 'Carbohydrate, by difference': 0.0, 'Sugars, total including NLEA': 0.55, 'Calcium, Ca': 10.0, 'Potassium, K': 379, 'Zinc, Zn': 5.44, 'Selenium, Se': 29.0, 'Vitamin E (alpha-tocopherol)': 0.53, 'Niacin': 5.68, 'Vitamin B-6': 0.668}
# There is no energy in  Squirrel, ground, meat (Alaska Native)
# {'Protein': 19.3, 'Energy': 111, 'Iron, Fe': 4.7, 'Phosphorus, P': 175, 'Total lipid (fat)': 3.8, 'Carbohydrate, by difference': 0.0}
# There is no energy in  Sesbania flower, raw
# {'Energy': 27.0, 'Folic acid': 0.0, 'Folate, DFE': 102, 'Vitamin A, RAE': 0.0, 'Protein': 1.28, 'Vitamin C, total ascorbic acid': 73.0, 'Thiamin': 0.083, 'Iron, Fe': 0.84, 'Magnesium, Mg': 12.0, 'Phosphorus, P': 30.0, 'Sodium, Na': 15.0, 'Cholesterol': 0.0, 'Riboflavin': 0.081, 'Vitamin B-12': 0.0, 'Total lipid (fat)': 0.04, 'Carbohydrate, by difference': 6.73, 'Calcium, Ca': 19.0, 'Potassium, K': 184, 'Niacin': 0.43, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.9}
# There is no energy in  Pancakes, buttermilk, prepared from recipe
# {'Energy': 227, 'Folate, DFE': 56.0, 'Folic acid': 25.0, 'Vitamin A, RAE': 30.0, 'Total lipid (fat)': 9.3, 'Carbohydrate, by difference': 28.7, 'Calcium, Ca': 157, 'Potassium, K': 145, 'Zinc, Zn': 0.62, 'Niacin': 1.58, 'Vitamin B-6': 0.045, 'Protein': 6.8, 'Iron, Fe': 1.7, 'Magnesium, Mg': 15.0, 'Phosphorus, P': 139, 'Sodium, Na': 522, 'Copper, Cu': 0.052, 'Vitamin B-12': 0.18, 'Cholesterol': 58.0, 'Fatty acids, total saturated': 1.83, 'Vitamin C, total ascorbic acid': 0.4, 'Thiamin': 0.204, 'Riboflavin': 0.292, 'Selenium, Se': 15.1}
# There is no energy in  Arrowhead, raw
# {'Energy': 99.0, 'Folic acid': 0.0, 'Folate, DFE': 14.0, 'Vitamin A, RAE': 0.0, 'Total lipid (fat)': 0.29, 'Carbohydrate, by difference': 20.2, 'Calcium, Ca': 10.0, 'Potassium, K': 922, 'Zinc, Zn': 0.28, 'Niacin': 1.65, 'Vitamin B-6': 0.26, 'Protein': 5.33, 'Vitamin C, total ascorbic acid': 1.1, 'Thiamin': 0.17, 'Riboflavin': 0.073, 'Vitamin B-12': 0.0, 'Iron, Fe': 2.57, 'Magnesium, Mg': 51.0, 'Phosphorus, P': 174, 'Sodium, Na': 22.0, 'Copper, Cu': 0.171, 'Cholesterol': 0.0, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.7}
# There is no energy in  Whale, bowhead, skin and subcutaneous fat (muktuk) (Alaska Native)
# {'Calcium, Ca': 5.0, 'Niacin': 0.8, 'Total lipid (fat)': 46.1, 'Protein': 12.6, 'Phosphorus, P': 87.0, 'Thiamin': 0.08, 'Riboflavin': 0.02, 'Cholesterol': 54.0, 'Fatty acids, total saturated': 6.56, 'Carbohydrate, by difference': 0.0, 'Energy': 466.0617}
# There is no energy in  Alcoholic Beverage, wine, table, red, Cabernet Sauvignon
# {'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 2.6, 'Protein': 0.07, 'Energy': 83.0}
# There is no energy in  Carissa, (natal-plum), raw
# {'Energy': 62.0, 'Vitamin A, RAE': 2.0, 'Protein': 0.5, 'Vitamin C, total ascorbic acid': 38.0, 'Thiamin': 0.04, 'Riboflavin': 0.06, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Iron, Fe': 1.31, 'Magnesium, Mg': 16.0, 'Phosphorus, P': 7.0, 'Sodium, Na': 3.0, 'Copper, Cu': 0.21, 'Total lipid (fat)': 1.3, 'Carbohydrate, by difference': 13.6, 'Calcium, Ca': 11.0, 'Potassium, K': 260, 'Niacin': 0.2}
# There is no energy in  Gravy, unspecified type, dry
# {'Energy': 344, 'Folate, DFE': 43.0, 'Vitamin C, total ascorbic acid': 7.0, 'Thiamin': 0.2, 'Riboflavin': 0.432, 'Iron, Fe': 1.0, 'Magnesium, Mg': 45.0, 'Phosphorus, P': 203, 'Sodium, Na': 5730.0, 'Copper, Cu': 0.1, 'Protein': 13.0, 'Vitamin B-12': 0.7, 'Cholesterol': 4.0, 'Fatty acids, total saturated': 2.86, 'Total lipid (fat)': 8.0, 'Carbohydrate, by difference': 58.0, 'Niacin': 3.7, 'Vitamin B-6': 0.1, 'Calcium, Ca': 150, 'Potassium, K': 262, 'Zinc, Zn': 1.4, 'Folic acid': 17.0, 'Vitamin A, RAE': 0.0, 'Selenium, Se': 6.1}
# There is no energy in  Alcoholic Beverage, wine, table, red, Syrah
# {'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 2.58, 'Protein': 0.07, 'Energy': 83.174088}
# There is no energy in  Fiddlehead ferns, frozen, unprepared
# {'Vitamin A, RAE': 168, 'Carotene, beta': 1870.0, 'Carotene, alpha': 280, 'Energy': 34.0, 'Carbohydrate, by difference': 5.74, 'Niacin': 3.26, 'Calcium, Ca': 24.0, 'Potassium, K': 129, 'Zinc, Zn': 0.71, 'Total lipid (fat)': 0.35, 'Iron, Fe': 0.73, 'Magnesium, Mg': 19.0, 'Phosphorus, P': 58.0, 'Sodium, Na': 0.0, 'Copper, Cu': 0.22, 'Vitamin C, total ascorbic acid': 17.8, 'Thiamin': 0.014, 'Riboflavin': 0.13, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Protein': 4.31, 'Vitamin D (D2 + D3)': 0.0}
# There is no energy in  Noodles, japanese, somen, cooked
# {'Energy': 131, 'Folic acid': 0.0, 'Folate, DFE': 2.0, 'Vitamin A, RAE': 0.0, 'Total lipid (fat)': 0.18, 'Carbohydrate, by difference': 27.5, 'Calcium, Ca': 8.0, 'Potassium, K': 29.0, 'Zinc, Zn': 0.22, 'Niacin': 0.097, 'Vitamin B-6': 0.013, 'Iron, Fe': 0.52, 'Protein': 4.0, 'Magnesium, Mg': 2.0, 'Phosphorus, P': 27.0, 'Sodium, Na': 161, 'Copper, Cu': 0.025, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.02, 'Riboflavin': 0.033, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.025, 'Vitamin D (D2 + D3)': 0.0}
# There is no energy in  Nuts, chestnuts, japanese, raw
# {'Energy': 154, 'Folic acid': 0.0, 'Folate, DFE': 47.0, 'Vitamin D (D2 + D3)': 0.0, 'Vitamin A, RAE': 2.0, 'Iron, Fe': 1.45, 'Magnesium, Mg': 49.0, 'Phosphorus, P': 72.0, 'Sodium, Na': 14.0, 'Copper, Cu': 0.562, 'Protein': 2.25, 'Vitamin C, total ascorbic acid': 26.3, 'Thiamin': 0.344, 'Riboflavin': 0.163, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.078, 'Niacin': 1.5, 'Vitamin B-6': 0.283, 'Total lipid (fat)': 0.53, 'Carbohydrate, by difference': 34.9, 'Calcium, Ca': 31.0, 'Potassium, K': 329, 'Zinc, Zn': 1.1}
# There is no energy in  Artificial Blueberry Muffin Mix, dry
# {'Energy': 407, 'Total lipid (fat)': 8.7, 'Carbohydrate, by difference': 77.4, 'Protein': 4.7, 'Sodium, Na': 760, 'Fatty acids, total saturated': 1.86}
# There is no energy in  Alcoholic Beverage, wine, table, red, Claret
# {'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 3.01, 'Protein': 0.07, 'Energy': 83.174088}
# There is no energy in  KFC, Fried Chicken, ORIGINAL RECIPE, Drumstick, meat and skin with breading
# {'Cholesterol': 117, 'Thiamin': 0.041, 'Riboflavin': 0.213, 'Vitamin B-12': 0.54, 'Iron, Fe': 0.97, 'Magnesium, Mg': 23.0, 'Phosphorus, P': 211, 'Sodium, Na': 625, 'Copper, Cu': 0.08, 'Calcium, Ca': 29.0, 'Potassium, K': 250, 'Zinc, Zn': 1.96, 'Selenium, Se': 25.5, 'Niacin': 4.99, 'Vitamin B-6': 0.221, 'Protein': 22.3, 'Energy': 239, 'Fatty acids, total saturated': 3.24, 'Total lipid (fat)': 14.2, 'Carbohydrate, by difference': 5.39}
# There is no energy in  Keebler, Keebler Chocolate Graham SELECTS
# {'Energy': 465, 'Fatty acids, total saturated': 3.15, 'Total lipid (fat)': 16.6, 'Carbohydrate, by difference': 71.8, 'Sugars, total including NLEA': 26.5, 'Protein': 7.1, 'Sodium, Na': 357}
# There is no energy in  Seeds, sesame flour, partially defatted
# {'Energy': 382, 'Folic acid': 0.0, 'Folate, DFE': 29.0, 'Vitamin D (D2 + D3)': 0.0, 'Vitamin A, RAE': 3.0, 'Niacin': 12.6, 'Vitamin B-6': 0.152, 'Total lipid (fat)': 11.9, 'Carbohydrate, by difference': 35.1, 'Calcium, Ca': 150, 'Potassium, K': 425, 'Zinc, Zn': 10.7, 'Iron, Fe': 14.3, 'Magnesium, Mg': 362, 'Phosphorus, P': 810, 'Sodium, Na': 41.0, 'Copper, Cu': 1.43, 'Protein': 40.3, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 2.53, 'Riboflavin': 0.27, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 1.63}
# There is no energy in  Snacks, corn cakes, very low sodium
# {'Energy': 387, 'Folic acid': 0.0, 'Folate, DFE': 19.0, 'Vitamin A, RAE': 12.0, 'Niacin': 5.15, 'Vitamin B-6': 0.14, 'Total lipid (fat)': 2.4, 'Carbohydrate, by difference': 83.4, 'Calcium, Ca': 19.0, 'Potassium, K': 157, 'Zinc, Zn': 2.0, 'Iron, Fe': 1.4, 'Magnesium, Mg': 114, 'Phosphorus, P': 157, 'Sodium, Na': 28.0, 'Copper, Cu': 0.42, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.25, 'Riboflavin': 0.05, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.42, 'Protein': 8.1, 'Selenium, Se': 9.9}
# There is no energy in  Noodles, japanese, soba, dry
# {'Energy': 336, 'Folic acid': 0.0, 'Folate, DFE': 60.0, 'Vitamin A, RAE': 0.0, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.136, 'Protein': 14.4, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.48, 'Riboflavin': 0.13, 'Iron, Fe': 2.7, 'Magnesium, Mg': 95.0, 'Phosphorus, P': 254, 'Sodium, Na': 792, 'Copper, Cu': 0.23, 'Niacin': 3.21, 'Total lipid (fat)': 0.71, 'Carbohydrate, by difference': 74.6, 'Calcium, Ca': 35.0, 'Potassium, K': 252, 'Zinc, Zn': 1.71, 'Vitamin B-6': 0.24, 'Vitamin D (D2 + D3)': 0.0}
# There is no energy in  Alcoholic Beverage, wine, table, red, Burgundy
# {'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 3.69, 'Protein': 0.07, 'Energy': 86.0}
# There is no energy in  Beverages, water, bottled, non-carbonated, DANNON
# {'Protein': 0.0, 'Energy': 0.0, 'Iron, Fe': 0.0, 'Magnesium, Mg': 1.0, 'Phosphorus, P': 0.0, 'Sodium, Na': 0.0, 'Copper, Cu': 0.0, 'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 3.0, 'Potassium, K': 0.0, 'Zinc, Zn': 0.0}
# There is no energy in  Fish, herring eggs, Pacific, plain (Alaska Native)
# {'Total lipid (fat)': 1.93, 'Carbohydrate, by difference': 4.47, 'Energy': 73.613848, 'Calcium, Ca': 19.0, 'Niacin': 1.8, 'Protein': 9.6, 'Iron, Fe': 2.7, 'Sodium, Na': 61.0, 'Vitamin C, total ascorbic acid': 0.6, 'Thiamin': 0.1, 'Riboflavin': 0.12, 'Cholesterol': 40.0, 'Fatty acids, total saturated': 0.43}
# There is no energy in  Squash, winter, butternut, frozen, cooked, boiled, with salt
# {'Folic acid': 0.0, 'Energy': 39.0, 'Carbohydrate, by difference': 10.0, 'Folate, DFE': 16.0, 'Vitamin A, RAE': 167, 'Protein': 1.23, 'Iron, Fe': 0.58, 'Magnesium, Mg': 9.0, 'Phosphorus, P': 14.0, 'Sodium, Na': 238, 'Copper, Cu': 0.036, 'Fatty acids, total saturated': 0.014, 'Vitamin C, total ascorbic acid': 3.5, 'Thiamin': 0.05, 'Riboflavin': 0.039, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Total lipid (fat)': 0.07, 'Calcium, Ca': 19.0, 'Potassium, K': 133, 'Zinc, Zn': 0.12, 'Niacin': 0.464, 'Vitamin B-6': 0.069, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.5}
# There is no energy in  McDONALD'S, Chicken McNUGGETS
# {'Thiamin': 0.16, 'Riboflavin': 0.11, 'Vitamin B-12': 0.33, 'Zinc, Zn': 0.59, 'Niacin': 7.4, 'Vitamin B-6': 0.398, 'Vitamin C, total ascorbic acid': 1.2, 'Cholesterol': 44.0, 'Fatty acids, total saturated': 3.26, 'Protein': 15.8, 'Energy': 302, 'Iron, Fe': 0.89, 'Magnesium, Mg': 24.0, 'Phosphorus, P': 272, 'Sodium, Na': 566, 'Copper, Cu': 0.049, 'Total lipid (fat)': 19.8, 'Carbohydrate, by difference': 15.1, 'Sugars, total including NLEA': 0.08, 'Calcium, Ca': 11.0, 'Potassium, K': 252}
# There is no energy in  Lamb, Australian, imported, fresh, shoulder, arm, separable lean and fat, trimmed to 1/8" fat, raw
# {'Energy': 243, 'Carbohydrate, by difference': 0.0, 'Selenium, Se': 6.5, 'Total lipid (fat)': 18.9, 'Niacin': 3.99, 'Vitamin B-6': 0.26, 'Calcium, Ca': 16.0, 'Potassium, K': 281, 'Zinc, Zn': 3.52, 'Protein': 17.1, 'Iron, Fe': 1.35, 'Magnesium, Mg': 19.0, 'Phosphorus, P': 168, 'Sodium, Na': 72.0, 'Copper, Cu': 0.12, 'Thiamin': 0.107, 'Riboflavin': 0.212, 'Vitamin B-12': 2.6, 'Cholesterol': 65.0, 'Fatty acids, total saturated': 9.12}
# There is no energy in  Chicken, broilers or fryers, neck, meat and skin, cooked, fried, batter
# {'Energy': 330, 'Folate, DFE': 21.0, 'Selenium, Se': 21.3, 'Folic acid': 8.0, 'Vitamin A, RAE': 51.0, 'Protein': 19.8, 'Iron, Fe': 2.15, 'Magnesium, Mg': 16.0, 'Phosphorus, P': 115, 'Sodium, Na': 276, 'Copper, Cu': 0.113, 'Vitamin B-12': 0.24, 'Cholesterol': 91.0, 'Fatty acids, total saturated': 6.22, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.1, 'Riboflavin': 0.237, 'Total lipid (fat)': 23.5, 'Carbohydrate, by difference': 8.7, 'Calcium, Ca': 31.0, 'Potassium, K': 151, 'Zinc, Zn': 2.5, 'Niacin': 4.53, 'Vitamin B-6': 0.21}
# There is no energy in  Alcoholic beverage, wine, table, white, late harvest, Gewurztraminer
# {'Energy': 108, 'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 11.4, 'Protein': 0.07}
# There is no energy in  Yambean (jicama), cooked, boiled, drained, without salt
# {'Energy': 38.0, 'Folic acid': 0.0, 'Folate, DFE': 8.0, 'Vitamin A, RAE': 1.0, 'Protein': 0.72, 'Vitamin C, total ascorbic acid': 14.1, 'Thiamin': 0.017, 'Riboflavin': 0.028, 'Vitamin B-12': 0.0, 'Iron, Fe': 0.57, 'Magnesium, Mg': 11.0, 'Phosphorus, P': 16.0, 'Sodium, Na': 4.0, 'Copper, Cu': 0.046, 'Cholesterol': 0.0, 'Total lipid (fat)': 0.09, 'Carbohydrate, by difference': 8.82, 'Calcium, Ca': 11.0, 'Potassium, K': 135, 'Zinc, Zn': 0.15, 'Niacin': 0.19, 'Vitamin B-6': 0.04, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.7}
# There is no energy in  HORMEL ALWAYS TENDER, Pork Loin Filets, Lemon Garlic-Flavored
# {'Energy': 118, 'Carbohydrate, by difference': 1.79, 'Total lipid (fat)': 4.16, 'Zinc, Zn': 1.3, 'Sugars, total including NLEA': 0.22, 'Protein': 17.8, 'Iron, Fe': 0.6, 'Sodium, Na': 590, 'Copper, Cu': 0.0, 'Fatty acids, total saturated': 1.41, 'Calcium, Ca': 6.0, 'Potassium, K': 542, 'Magnesium, Mg': 20.0, 'Vitamin C, total ascorbic acid': 1.7, 'Cholesterol': 42.0}
# There is no energy in  Popovers, dry mix, enriched
# {'Energy': 371, 'Folate, DFE': 229, 'Folic acid': 120, 'Vitamin A, RAE': 0.0, 'Niacin': 3.38, 'Total lipid (fat)': 4.3, 'Carbohydrate, by difference': 71.0, 'Calcium, Ca': 32.0, 'Potassium, K': 100, 'Protein': 10.4, 'Iron, Fe': 2.97, 'Magnesium, Mg': 25.0, 'Phosphorus, P': 100, 'Sodium, Na': 906, 'Fatty acids, total saturated': 0.983, 'Thiamin': 0.43, 'Riboflavin': 0.147, 'Vitamin B-6': 0.042, 'Zinc, Zn': 0.88, 'Selenium, Se': 37.6, 'Vitamin C, total ascorbic acid': 0.1, 'Cholesterol': 0.0, 'Vitamin B-12': 0.08, 'Copper, Cu': 0.171}
# There is no energy in  Mouse nuts, roots (Alaska Native)
# {'Protein': 3.9, 'Energy': 81.0, 'Phosphorus, P': 175, 'Vitamin C, total ascorbic acid': 16.0, 'Thiamin': 0.01, 'Riboflavin': 0.04, 'Total lipid (fat)': 0.1, 'Carbohydrate, by difference': 16.1, 'Calcium, Ca': 22.0, 'Niacin': 0.1}
# There is no energy in  Corn, dried (Navajo)
# {'Protein': 9.88, 'Energy': 386, 'Iron, Fe': 1.92, 'Magnesium, Mg': 124, 'Phosphorus, P': 337, 'Sodium, Na': 13.0, 'Copper, Cu': 0.195, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.2, 'Riboflavin': 0.068, 'Vitamin K (phylloquinone)': 0.9, 'Fatty acids, total saturated': 0.82, 'Total lipid (fat)': 5.22, 'Carbohydrate, by difference': 74.9, 'Sugars, total including NLEA': 5.38, 'Calcium, Ca': 15.0, 'Potassium, K': 511, 'Zinc, Zn': 3.05, 'Vitamin E (alpha-tocopherol)': 0.0, 'Niacin': 3.3, 'Vitamin B-6': 0.372}
# There is no energy in  Beans, navy, mature seeds, sprouted, raw
# {'Energy': 67.0, 'Folic acid': 0.0, 'Folate, DFE': 132, 'Vitamin A, RAE': 0.0, 'Total lipid (fat)': 0.7, 'Carbohydrate, by difference': 13.0, 'Calcium, Ca': 15.0, 'Potassium, K': 307, 'Zinc, Zn': 0.89, 'Niacin': 1.22, 'Vitamin B-6': 0.191, 'Protein': 6.15, 'Vitamin C, total ascorbic acid': 18.8, 'Thiamin': 0.39, 'Riboflavin': 0.215, 'Vitamin B-12': 0.0, 'Iron, Fe': 1.93, 'Magnesium, Mg': 101, 'Phosphorus, P': 100, 'Sodium, Na': 13.0, 'Copper, Cu': 0.356, 'Fatty acids, total saturated': 0.085, 'Cholesterol': 0.0, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.6}
# There is no energy in  Lamb, Australian, imported, fresh, leg, shank half, separable lean and fat, trimmed to 1/8" fat, cooked, roasted
# {'Energy': 231, 'Carbohydrate, by difference': 0.0, 'Total lipid (fat)': 13.7, 'Vitamin B-6': 0.429, 'Calcium, Ca': 10.0, 'Potassium, K': 313, 'Zinc, Zn': 4.49, 'Selenium, Se': 10.6, 'Niacin': 5.42, 'Protein': 25.2, 'Vitamin B-12': 3.04, 'Cholesterol': 83.0, 'Fatty acids, total saturated': 6.34, 'Iron, Fe': 2.01, 'Magnesium, Mg': 23.0, 'Phosphorus, P': 203, 'Sodium, Na': 67.0, 'Copper, Cu': 0.138, 'Thiamin': 0.127, 'Riboflavin': 0.39}
# There is no energy in  Pancakes, special dietary, dry mix
# {'Energy': 349, 'Folate, DFE': 172, 'Folic acid': 93.0, 'Vitamin A, RAE': 6.0, 'Total lipid (fat)': 1.4, 'Carbohydrate, by difference': 73.9, 'Calcium, Ca': 99.0, 'Potassium, K': 676, 'Zinc, Zn': 1.19, 'Niacin': 3.27, 'Vitamin B-6': 0.037, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.37, 'Riboflavin': 0.209, 'Protein': 8.9, 'Iron, Fe': 3.05, 'Magnesium, Mg': 47.0, 'Phosphorus, P': 596, 'Sodium, Na': 456, 'Copper, Cu': 0.137, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.202, 'Selenium, Se': 25.1}
# There is no energy in  Deer (venison), sitka, raw (Alaska Native)
# {'Energy': 115.678904, 'Vitamin A, RAE': 0.0, 'Total lipid (fat)': 2.66, 'Calcium, Ca': 7.0, 'Niacin': 6.6, 'Protein': 21.5, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.2, 'Riboflavin': 0.36, 'Cholesterol': 18.0, 'Fatty acids, total saturated': 0.63, 'Iron, Fe': 2.9, 'Carbohydrate, by difference': 0.0}
# There is no energy in  Vinespinach, (basella), raw
# {'Energy': 19.0, 'Folic acid': 0.0, 'Folate, DFE': 140, 'Vitamin A, RAE': 400, 'Total lipid (fat)': 0.3, 'Carbohydrate, by difference': 3.4, 'Calcium, Ca': 109, 'Potassium, K': 510, 'Zinc, Zn': 0.43, 'Niacin': 0.5, 'Vitamin B-6': 0.24, 'Protein': 1.8, 'Iron, Fe': 1.2, 'Magnesium, Mg': 65.0, 'Phosphorus, P': 52.0, 'Sodium, Na': 24.0, 'Copper, Cu': 0.107, 'Vitamin C, total ascorbic acid': 102, 'Thiamin': 0.05, 'Riboflavin': 0.155, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.8}
# There is no energy in  Soup, chicken broth cubes, dry, prepared with water
# {'Folic acid': 0.0, 'Iron, Fe': 0.05, 'Magnesium, Mg': 1.0, 'Phosphorus, P': 5.0, 'Sodium, Na': 326, 'Copper, Cu': 0.0, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.005, 'Riboflavin': 0.01, 'Vitamin B-12': 0.01, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 0.03, 'Protein': 0.39, 'Total lipid (fat)': 0.12, 'Carbohydrate, by difference': 0.62, 'Energy': 5.019126, 'Calcium, Ca': 5.0, 'Potassium, K': 10.0, 'Zinc, Zn': 0.01, 'Niacin': 0.103, 'Vitamin B-6': 0.0, 'Vitamin A, RAE': 1.0, 'Folate, DFE': 1.0}
# There is no energy in  KFC, Fried Chicken, EXTRA CRISPY, Drumstick, meat only, skin and breading removed
# {'Thiamin': 0.05, 'Riboflavin': 0.262, 'Vitamin B-12': 0.63, 'Cholesterol': 137, 'Iron, Fe': 1.05, 'Magnesium, Mg': 23.0, 'Phosphorus, P': 224, 'Sodium, Na': 526, 'Copper, Cu': 0.084, 'Calcium, Ca': 16.0, 'Potassium, K': 273, 'Zinc, Zn': 2.51, 'Selenium, Se': 30.9, 'Niacin': 5.24, 'Vitamin B-6': 0.247, 'Fatty acids, total saturated': 1.89, 'Protein': 25.9, 'Energy': 170, 'Total lipid (fat)': 7.43, 'Carbohydrate, by difference': 0.0}
# There is no energy in  Taro shoots, cooked, without salt
# {'Energy': 14.0, 'Folic acid': 0.0, 'Folate, DFE': 3.0, 'Vitamin A, RAE': 3.0, 'Total lipid (fat)': 0.08, 'Carbohydrate, by difference': 3.2, 'Calcium, Ca': 14.0, 'Potassium, K': 344, 'Zinc, Zn': 0.54, 'Niacin': 0.81, 'Vitamin B-6': 0.112, 'Cholesterol': 0.0, 'Vitamin C, total ascorbic acid': 18.9, 'Thiamin': 0.038, 'Riboflavin': 0.053, 'Vitamin B-12': 0.0, 'Iron, Fe': 0.41, 'Magnesium, Mg': 8.0, 'Phosphorus, P': 26.0, 'Sodium, Na': 2.0, 'Copper, Cu': 0.094, 'Protein': 0.73, 'Fatty acids, total saturated': 0.016, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 1.0}
# There is no energy in  Buffalo, free range, top round steak, cooked (Shoshone Bannock)
# {'Protein': 32.5, 'Energy': 146, 'Iron, Fe': 3.76, 'Magnesium, Mg': 27.0, 'Phosphorus, P': 246, 'Sodium, Na': 41.0, 'Copper, Cu': 0.189, 'Thiamin': 0.169, 'Riboflavin': 0.462, 'Vitamin B-12': 1.67, 'Cholesterol': 82.0, 'Fatty acids, total saturated': 0.595, 'Vitamin B-6': 0.794, 'Folic acid': 0.0, 'Folate, DFE': 8.0, 'Total lipid (fat)': 1.8, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 4.0, 'Potassium, K': 376, 'Zinc, Zn': 5.06, 'Selenium, Se': 10.5, 'Vitamin E (alpha-tocopherol)': 0.59, 'Niacin': 7.02}
# There is no energy in  Fish, whitefish, broad, head, eyes, cheeks and soft bones (Alaska Native)
# {'Total lipid (fat)': 3.6, 'Carbohydrate, by difference': 0.0, 'Energy': 106.83568199999999, 'Protein': 18.6, 'Iron, Fe': 3.9, 'Phosphorus, P': 242}
# There is no energy in  Lentils, sprouted, cooked, stir-fried, without salt
# {'Energy': 101, 'Folic acid': 0.0, 'Folate, DFE': 67.0, 'Vitamin A, RAE': 2.0, 'Fatty acids, total saturated': 0.053, 'Vitamin C, total ascorbic acid': 12.6, 'Thiamin': 0.22, 'Riboflavin': 0.09, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Protein': 8.8, 'Iron, Fe': 3.1, 'Magnesium, Mg': 35.0, 'Phosphorus, P': 153, 'Sodium, Na': 10.0, 'Copper, Cu': 0.337, 'Total lipid (fat)': 0.45, 'Carbohydrate, by difference': 21.2, 'Calcium, Ca': 14.0, 'Potassium, K': 284, 'Zinc, Zn': 1.6, 'Niacin': 1.2, 'Vitamin B-6': 0.164, 'Vitamin D (D2 + D3)': 0.0, 'Selenium, Se': 0.6}
# There is no energy in  Mckee Baking, Little Debbie Nutty Bars, Wafers with Peanut Butter, Chocolate Covered
# {'Energy': 548, 'Total lipid (fat)': 32.8, 'Carbohydrate, by difference': 55.2, 'Sugars, total including NLEA': 34.0, 'Protein': 8.0, 'Sodium, Na': 223, 'Vitamin C, total ascorbic acid': 2.0, 'Fatty acids, total saturated': 6.29}
# There is no energy in  Beverages, water, bottled, non-carbonated, CRYSTAL GEYSER
# {'Protein': 0.0, 'Energy': 0.0, 'Magnesium, Mg': 0.0, 'Sodium, Na': 1.0, 'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 3.0, 'Potassium, K': 0.0}
# There is no energy in  Beverages, V8 SPLASH Juice Drinks, Strawberry Banana
# {'Protein': 0.0, 'Energy': 29.0, 'Sodium, Na': 21.0, 'Vitamin C, total ascorbic acid': 24.7, 'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 7.41, 'Sugars, total including NLEA': 7.41, 'Potassium, K': 8.0, 'Vitamin E (alpha-tocopherol)': 1.11}
# There is no energy in  Alcoholic beverage, wine, table, white, Muscat
# {'Protein': 0.07, 'Total lipid (fat)': 0.0, 'Carbohydrate, by difference': 5.23, 'Energy': 81.740052}
# There is no energy in  Tofu, salted and fermented (fuyu), prepared with calcium sulfate
# {'Folic acid': 0.0, 'Folate, DFE': 29.0, 'Energy': 115.91790999999999, 'Vitamin A, RAE': 0.0, 'Protein': 8.15, 'Carbohydrate, by difference': 5.15, 'Vitamin D (D2 + D3)': 0.0, 'Iron, Fe': 1.98, 'Magnesium, Mg': 58.0, 'Phosphorus, P': 73.0, 'Sodium, Na': 2870.0, 'Copper, Cu': 0.376, 'Vitamin C, total ascorbic acid': 0.2, 'Thiamin': 0.157, 'Riboflavin': 0.101, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 1.16, 'Total lipid (fat)': 8.0, 'Calcium, Ca': 1230.0, 'Potassium, K': 75.0, 'Zinc, Zn': 1.56, 'Niacin': 0.379, 'Vitamin B-6': 0.091, 'Selenium, Se': 17.3}
# There is no energy in  Game meat, bison, top sirloin, separable lean only, trimmed to 0" fat, raw
# {'Energy': 113, 'Fatty acids, total saturated': 0.885, 'Protein': 21.4, 'Total lipid (fat)': 2.4, 'Riboflavin': 0.097, 'Niacin': 2.02, 'Vitamin A, RAE': 1.0, 'Vitamin B-6': 0.259, 'Carbohydrate, by difference': 0.0, 'Calcium, Ca': 5.0, 'Potassium, K': 335, 'Zinc, Zn': 3.4, 'Selenium, Se': 25.1, 'Vitamin E (alpha-tocopherol)': 0.05, 'Vitamin B-12': 2.3, 'Iron, Fe': 3.0, 'Magnesium, Mg': 24.0, 'Phosphorus, P': 203, 'Sodium, Na': 51.0, 'Copper, Cu': 0.155, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.045, 'Cholesterol': 71.0}
# There is no energy in  Pasta, homemade, made with egg, cooked
# {'Energy': 130, 'Folate, DFE': 60.0, 'Folic acid': 24.0, 'Vitamin A, RAE': 17.0, 'Total lipid (fat)': 1.74, 'Carbohydrate, by difference': 23.5, 'Calcium, Ca': 10.0, 'Potassium, K': 21.0, 'Zinc, Zn': 0.44, 'Niacin': 1.26, 'Vitamin B-6': 0.037, 'Protein': 5.28, 'Iron, Fe': 1.16, 'Magnesium, Mg': 14.0, 'Phosphorus, P': 52.0, 'Sodium, Na': 83.0, 'Copper, Cu': 0.056, 'Vitamin C, total ascorbic acid': 0.0, 'Thiamin': 0.173, 'Riboflavin': 0.174, 'Vitamin B-12': 0.1, 'Cholesterol': 41.0, 'Fatty acids, total saturated': 0.408}
# There is no energy in  KFC, Fried Chicken, ORIGINAL RECIPE, Thigh, meat only, skin and breading removed
# {'Calcium, Ca': 20.0, 'Protein': 22.8, 'Energy': 175, 'Iron, Fe': 0.87, 'Magnesium, Mg': 20.0, 'Phosphorus, P': 213, 'Sodium, Na': 568, 'Copper, Cu': 0.082, 'Vitamin A, RAE': 11.0, 'Thiamin': 0.089, 'Riboflavin': 0.31, 'Vitamin B-12': 0.47, 'Cholesterol': 122, 'Fatty acids, total saturated': 2.31, 'Choline, total': 117, 'Potassium, K': 230, 'Zinc, Zn': 1.91, 'Selenium, Se': 28.7, 'Vitamin E (alpha-tocopherol)': 0.41, 'Niacin': 5.61, 'Vitamin B-6': 0.137, 'Total lipid (fat)': 9.31, 'Carbohydrate, by difference': 0.01}
# There is no energy in  Nuts, coconut milk, frozen (liquid expressed from grated meat and water)
# {'Energy': 202, 'Folic acid': 0.0, 'Folate, DFE': 14.0, 'Vitamin D (D2 + D3)': 0.0, 'Vitamin A, RAE': 0.0, 'Iron, Fe': 0.81, 'Magnesium, Mg': 32.0, 'Phosphorus, P': 59.0, 'Sodium, Na': 12.0, 'Copper, Cu': 0.235, 'Protein': 1.61, 'Vitamin C, total ascorbic acid': 1.1, 'Thiamin': 0.023, 'Riboflavin': 0.0, 'Vitamin B-12': 0.0, 'Cholesterol': 0.0, 'Fatty acids, total saturated': 18.4, 'Total lipid (fat)': 20.8, 'Carbohydrate, by difference': 5.58, 'Calcium, Ca': 4.0, 'Potassium, K': 232, 'Zinc, Zn': 0.59, 'Niacin': 0.671, 'Vitamin B-6': 0.03}
# There is no energy in  Gravy, HEINZ Home Style, classic chicken
# {'Total lipid (fat)': 2.57, 'Carbohydrate, by difference': 5.01, 'Energy': 45.889151999999996, 'Sugars, total including NLEA': 0.0, 'Calcium, Ca': 10.0, 'Potassium, K': 35.0, 'Zinc, Zn': 0.08, 'Selenium, Se': 0.4, 'Vitamin E (alpha-tocopherol)': 0.11, 'Niacin': 0.28, 'Vitamin B-6': 0.027, 'Protein': 0.67, 'Iron, Fe': 0.07, 'Magnesium, Mg': 3.0, 'Phosphorus, P': 22.0, 'Sodium, Na': 372, 'Copper, Cu': 0.019, 'Thiamin': 0.03, 'Riboflavin': 0.057, 'Vitamin B-12': 0.0, 'Vitamin K (phylloquinone)': 0.8, 'Cholesterol': 4.0, 'Fatty acids, total saturated': 0.656}
# There is no energy in  Grapefruit, raw, white, California
# {'Energy': 37.0, 'Folic acid': 0.0, 'Total lipid (fat)': 0.1, 'Carbohydrate, by difference': 9.09, 'Calcium, Ca': 12.0, 'Potassium, K': 143, 'Zinc, Zn': 0.07, 'Niacin': 0.269, 'Vitamin B-6': 0.043, 'Protein': 0.88, 'Iron, Fe': 0.08, 'Magnesium, Mg': 9.0, 'Phosphorus, P': 12.0, 'Sodium, Na': 0.0, 'Copper, Cu': 0.032, 'Fatty acids, total saturated': 0.014, 'Cholesterol': 0.0, 'Vitamin C, total ascorbic acid': 33.3, 'Thiamin': 0.037, 'Riboflavin': 0.02, 'Vitamin B-12': 0.0, 'Vitamin A, RAE': 0.0, 'Folate, DFE': 12.0, 'Vitamin D (D2 + D3)': 0.0}
# There is no energy in  Soy meal, defatted, raw
# ...
#  'Restaurant, family style, sirloin steak',
#  'Squirrel, ground, meat (Alaska Native)',
#  'Sesbania flower, raw',
#  'Pancakes, buttermilk, prepared from recipe',
#  'Arrowhead, raw',
#  'Whale, bowhead, skin and subcutaneous fat (muktuk) (Alaska Native)',
#  'Alcoholic Beverage, wine, table, red, Cabernet Sauvignon',
#  'Carissa, (natal-plum), raw',
#  'Gravy, unspecified type, dry',
#  'Alcoholic Beverage, wine, table, red, Syrah',
#  'Fiddlehead ferns, frozen, unprepared',
#  'Noodles, japanese, somen, cooked',
#  'Nuts, chestnuts, japanese, raw',
#  'Artificial Blueberry Muffin Mix, dry',
#  'Alcoholic Beverage, wine, table, red, Claret',
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Drumstick, meat and skin with breading',
#  'Keebler, Keebler Chocolate Graham SELECTS',
#  'Seeds, sesame flour, partially defatted',
#  'Snacks, corn cakes, very low sodium',
#  'Noodles, japanese, soba, dry',
#  'Alcoholic Beverage, wine, table, red, Burgundy',
#  'Beverages, water, bottled, non-carbonated, DANNON',
#  'Fish, herring eggs, Pacific, plain (Alaska Native)',
#  'Squash, winter, butternut, frozen, cooked, boiled, with salt',
#  "McDONALD'S, Chicken McNUGGETS",
#  'Lamb, Australian, imported, fresh, shoulder, arm, separable lean and fat, trimmed to 1/8" fat, raw',
#  'Chicken, broilers or fryers, neck, meat and skin, cooked, fried, batter',
#  'Alcoholic beverage, wine, table, white, late harvest, Gewurztraminer',
#  'Yambean (jicama), cooked, boiled, drained, without salt',
#  'HORMEL ALWAYS TENDER, Pork Loin Filets, Lemon Garlic-Flavored',
#  'Popovers, dry mix, enriched',
#  'Mouse nuts, roots (Alaska Native)',
#  'Corn, dried (Navajo)',
#  'Beans, navy, mature seeds, sprouted, raw',
#  'Lamb, Australian, imported, fresh, leg, shank half, separable lean and fat, trimmed to 1/8" fat, cooked, roasted',
#  'Pancakes, special dietary, dry mix',
#  'Deer (venison), sitka, raw (Alaska Native)',
#  'Vinespinach, (basella), raw',
#  'Soup, chicken broth cubes, dry, prepared with water',
#  'KFC, Fried Chicken, EXTRA CRISPY, Drumstick, meat only, skin and breading removed',
#  'Taro shoots, cooked, without salt',
#  'Buffalo, free range, top round steak, cooked (Shoshone Bannock)',
#  'Fish, whitefish, broad, head, eyes, cheeks and soft bones (Alaska Native)',
#  'Lentils, sprouted, cooked, stir-fried, without salt',
#  'Mckee Baking, Little Debbie Nutty Bars, Wafers with Peanut Butter, Chocolate Covered',
#  'Beverages, water, bottled, non-carbonated, CRYSTAL GEYSER',
#  'Beverages, V8 SPLASH Juice Drinks, Strawberry Banana',
#  'Alcoholic beverage, wine, table, white, Muscat',
#  'Tofu, salted and fermented (fuyu), prepared with calcium sulfate',
#  'Game meat, bison, top sirloin, separable lean only, trimmed to 0" fat, raw',
#  'Pasta, homemade, made with egg, cooked',
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Thigh, meat only, skin and breading removed',
#  'Nuts, coconut milk, frozen (liquid expressed from grated meat and water)',
#  'Gravy, HEINZ Home Style, classic chicken',
#  'Grapefruit, raw, white, California',
#  'Soy meal, defatted, raw',
#  'Taro, shoots, cooked, with salt',
#  'Nuts, chestnuts, chinese, roasted',
#  'Beverages, V8 SPLASH Juice Drinks, Diet Fruit Medley',
#  'Alcoholic Beverage, wine, table, red, Sangiovese',
#  'Lamb, Australian, imported, fresh, leg, center slice, bone-in, separable lean only, trimmed to 1/8" fat, raw',
#  'Cowpeas, leafy tips, raw',
#  'Beverages, V8 SPLASH Juice Drinks, Diet Strawberry Kiwi',
#  'Pepeao, dried',
#  'Seeds, safflower seed kernels, dried',
#  'Gravy, chicken, dry',
#  'Chicken, broilers or fryers, skin only, cooked, fried, flour',
#  'Stew, dumpling with mutton (Navajo)',
#  'Winged bean, immature seeds, cooked, boiled, drained, with salt',
#  'Bread, reduced-calorie, oatmeal',
#  'Noodles, japanese, soba, cooked',
#  'Winged beans, immature seeds, cooked, boiled, drained, without salt',
#  'Lemon grass (citronella), raw',
#  'Gravy, turkey, dry',
#  'Veal, breast, whole, boneless, separable lean only, cooked, braised',
#  'Balsam-pear (bitter gourd), leafy tips, raw',
#  'Huckleberries, raw (Alaska Native)',
#  'Cheese, dry white, queso seco',
#  'Rice, white, short-grain, raw, unenriched',
#  'Yardlong bean, cooked, boiled, drained, with salt',
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Drumstick, meat only, skin and breading removed',
#  'Lamb, Australian, imported, fresh, leg, whole (shank and sirloin), separable lean only, trimmed to 1/8" fat, cooked, roasted',
#  'Beverages, V8 SPLASH Juice Drinks, Orchard Blend',
#  'Alcoholic beverage, wine, table, white, late harvest',
#  'Wheat, durum',
#  'Lamb, Australian, imported, fresh, leg, whole (shank and sirloin), separable lean and fat, trimmed to 1/8" fat, raw',
#  'Beans, pinto, mature seeds, sprouted, cooked, boiled, drained, with salt',
#  'Alcoholic beverage, wine, table, white, Chenin Blanc',
#  'Tempeh',
#  'Beverages, V8 SPLASH Juice Drinks, Fruit Medley',
#  'Roselle, raw',
#  'Nuts, coconut meat, dried (desiccated), toasted',
#  "Jew's ear, (pepeao), raw",
#  'Grapefruit juice, pink, raw',
#  'Apricots, dehydrated (low-moisture), sulfured, uncooked',
#  'Walrus, meat, raw (Alaska Native)',
#  'Lamb, Australian, imported, fresh, shoulder, arm, separable lean only, trimmed to 1/8" fat, raw',
#  'Lamb, Australian, imported, fresh, leg, whole (shank and sirloin), separable lean and fat, trimmed to 1/8" fat, cooked, roasted',
#  'Hyacinth beans, mature seeds, cooked, boiled, with salt',
#  'Pie, apple, prepared from recipe',
#  'HORMEL ALWAYS TENDER, Pork Tenderloin, Peppercorn-Flavored',
#  'Lamb, Australian, imported, fresh, composite of trimmed retail cuts, separable lean and fat, trimmed to 1/8" fat, raw',
#  'Cowpeas, young pods with seeds, cooked, boiled, drained, without salt',
#  'Seeds, sesame meal, partially defatted',
#  'Cockles, raw (Alaska Native)',
#  'Seal, ringed, meat (Alaska Native)',
#  'KFC, Fried Chicken, EXTRA CRISPY, Wing, meat only, skin and breading removed',
#  'Peaches, dehydrated (low-moisture), sulfured, uncooked',
#  'Horned melon (Kiwano)',
#  'Butterbur, cooked, boiled, drained, without salt',
#  'Veal, shank (fore and hind), separable lean and fat, cooked, braised',
#  'Mountain yam, hawaii, cooked, steamed, without salt',
#  'Lamb, Australian, imported, fresh, foreshank, separable lean and fat, trimmed to 1/8" fat, raw',
#  'Lamb, Australian, imported, fresh, loin, separable lean and fat, trimmed to 1/8" fat, cooked, broiled',
#  'French toast, prepared from recipe, made with low fat (2%) milk',
#  'Snacks, beef sticks, smoked',
#  'Vinegar, balsamic',
#  'Beverages, V8 SPLASH Juice Drinks, Mango Peach',
#  'Pie, pumpkin, prepared from recipe',
#  'Agutuk, fish with shortening (Alaskan ice cream) (Alaska Native)',
#  'BURGER KING, Double Cheeseburger',
#  'Crustaceans, shrimp, cooked',
#  'Lamb, Australian, imported, fresh, shoulder, whole (arm and blade), separable lean and fat, trimmed to 1/8" fat, cooked',
#  'Sweet rolls, cinnamon, refrigerated dough with frosting',
#  'Caribou, tongue, raw (Alaska Native)',
#  'Oil, bearded seal (Oogruk) (Alaska Native)',
#  'Pie, chocolate mousse, prepared from mix, no-bake type',
#  'Elk, free range, ground, cooked patties (Shoshone Bannock)',
#  'Seeds, sesame flour, high-fat',
#  'Rhubarb, wild, leaves (Alaska Native)',
#  'Pancakes, plain, prepared from recipe',
#  'Snacks, trail mix, regular',
#  'Seal, bearded (Oogruk), meat, partially dried (Alaska Native)',
#  'Amaranth leaves, cooked, boiled, drained, without salt',
#  'Fish, pollock, Alaska, raw',
#  'Ascidians (tunughnak) (Alaska Native)',
#  'Alcoholic beverage, wine, table, white, Semillon',
#  'Willow, leaves in oil (Alaska Native)',
#  'Fish, salmon, king, chinook, smoked and canned (Alaska Native)',
#  'Blueberries, wild, frozen (Alaska Native)',
#  'Rice, white, medium-grain, cooked, unenriched',
#  'Pie, blueberry, prepared from recipe',
#  'Duck, young duckling, domesticated, White Pekin, leg, meat and skin, bone in, cooked, roasted',
#  'Veal, breast, plate half, boneless, separable lean and fat, cooked, braised',
#  'Tea, herbal, brewed, Hohoysi (Hopi)',
#  'Nuts, chestnuts, chinese, dried',
#  "DENNY'S, top sirloin steak",
#  'Vitasoy USA Nasoya, Lite Silken Tofu',
#  'Winged beans, immature seeds, raw',
#  'Lamb, Australian, imported, fresh, foreshank, separable lean and fat, trimmed to 1/8" fat, cooked, braised',
#  'Groundcherries, (cape-gooseberries or poha), raw',
#  'Bread, kneel down (Navajo)',
#  'Winged beans, mature seeds, cooked, boiled, without salt',
#  'Lamb, Australian, imported, fresh, loin, separable lean only, trimmed to 1/8" fat, raw',
#  'Lamb, Australian, imported, fresh, foreshank, separable lean only, trimmed to 1/8" fat, cooked, braised',
#  'Cabbage, napa, cooked',
#  'Seeds, watermelon seed kernels, dried',
#  'Yardlong bean, raw',
#  'HORMEL ALWAYS TENDER, Pork Tenderloin, Teriyaki-Flavored',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, fried, flour',
#  'Alcoholic Beverage, wine, table, red, Barbera',
#  'Snacks, trail mix, tropical',
#  'Mission Foods, Mission Flour Tortillas, Soft Taco, 8 inch',
#  'Taro, tahitian, cooked, without salt',
#  'Taro, tahitian, cooked, with salt',
#  'Amaranth leaves, cooked, boiled, drained, with salt',
#  'Whale, bowhead, subcutaneous fat (blubber) (Alaska Native)',
#  'Taro shoots, raw',
#  'Muffins, wheat bran, dry mix',
#  'Tempeh, cooked',
#  "Gravy, CAMPBELL'S, chicken",
#  'Lamb, Australian, imported, fresh, leg, sirloin half, boneless, separable lean only, trimmed to 1/8" fat, cooked, roasted',
#  'Okara',
#  'Lamb, Australian, imported, fresh, leg, sirloin half, boneless, separable lean only, trimmed to 1/8" fat, raw',
#  'Cherry juice, tart',
#  'Butterbur, cooked, boiled, drained, with salt',
#  'Cornsalad, raw',
#  'Beverages, water, bottled, non-carbonated, CALISTOGA',
#  'Sesbania flower, cooked, steamed, with salt',
#  'Bread, cornbread, prepared from recipe, made with low fat (2%) milk',
#  'Alcoholic Beverage, wine, table, red, Pinot Noir',
#  'Lamb, Australian, imported, fresh, leg, sirloin half, boneless, separable lean and fat, trimmed to 1/8" fat, cooked, roasted',
#  "APPLEBEE'S, 9 oz house sirloin steak",
#  'Alcoholic Beverage, wine, table, red, Zinfandel',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, fried, batter',
#  'Nuts, chestnuts, european, raw, peeled',
#  'Alcoholic beverage, wine, table, white, Muller Thurgau',
#  'Beverages, V8 SPLASH Juice Drinks, Diet Tropical Blend',
#  'Duck, young duckling, domesticated, White Pekin, breast, meat only, boneless, cooked without skin, broiled',
#  'Sugar, turbinado',
#  'Duck, scoter, white-winged, meat (Alaska Native)',
#  'Oil, flaxseed, contains added sliced flaxseed',
#  'Peas, mature seeds, sprouted, raw',
#  "T.G.I. FRIDAY'S, FRIDAY'S Shrimp, breaded",
#  'Yambean (jicama), cooked, boiled, drained, with salt',
#  'KFC, Fried Chicken, EXTRA CRISPY, Thigh, meat and skin with breading',
#  'Chicken, broilers or fryers, light meat, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, neck, meat and skin, cooked, fried, flour',
#  'Snacks, trail mix, regular, unsalted',
#  'Pie, pecan, prepared from recipe',
#  'Cowpeas, leafy tips, cooked, boiled, drained, with salt',
#  'KFC, Fried Chicken, EXTRA CRISPY, Thigh, meat only, skin and breading removed',
#  'Soup, fish, homemade (Alaska Native)',
#  'Radish seeds, sprouted, raw',
#  'Purslane, raw',
#  'Alcoholic beverage, wine, table, white, Riesling',
#  'Cranberry, low bush or lingenberry, raw (Alaska Native)',
#  'Fish, herring, Pacific, flesh, air-dried, packed in oil (Alaska Native)',
#  'Seeds, safflower seed meal, partially defatted',
#  'Peas, mature seeds, sprouted, cooked, boiled, drained, without salt',
#  'Lamb, Australian, imported, fresh, leg, shank half, separable lean only, trimmed to 1/8" fat, cooked, roasted',
#  'Tofu, salted and fermented (fuyu)',
#  'Caribou, bone marrow, raw (Alaska Native)',
#  'Lamb, Australian, imported, fresh, composite of trimmed retail cuts, separable lean only, trimmed to 1/8" fat, cooked',
#  'Seal, ringed, liver (Alaska Native)',
#  'Nuts, ginkgo nuts, raw',
#  'Java-plum, (jambolan), raw',
#  'Eppaw, raw',
#  'Seeds, breadnut tree seeds, raw',
#  'KFC, Fried Chicken, EXTRA CRISPY, Wing, meat and skin with breading',
#  'Biscuits, mixed grain, refrigerated dough',
#  'Lemon juice from concentrate, bottled, CONCORD',
#  'Lamb, Australian, imported, fresh, shoulder, blade, separable lean only, trimmed to 1/8" fat, raw',
#  'Lamb, Australian, imported, fresh, leg, center slice, bone-in, separable lean and fat, trimmed to 1/8" fat, raw',
#  'Nuts, chestnuts, japanese, roasted',
#  'Oopah (tunicate), whole animal (Alaska Native)',
#  'Purslane, cooked, boiled, drained, without salt',
#  'Walrus, meat and subcutaneous fat raw (Alaska Native)',
#  "WENDY'S, Double Stack, with cheese",
#  'KFC, Fried Chicken, EXTRA CRISPY, Breast, meat only, skin and breading removed',
#  'Fish, lingcod, liver (Alaska Native)',
#  'Gravy, au jus, dry',
#  'Fiddlehead ferns, raw',
#  'Nuts, chestnuts, japanese, boiled and steamed',
#  'Nuts, beechnuts, dried',
#  'Beans, navy, mature seeds, sprouted, cooked, boiled, drained, without salt',
#  'Beans, navy, mature seeds, sprouted, cooked, boiled, drained, with salt',
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Breast, meat and skin with breading',
#  'Prunes, dehydrated (low-moisture), stewed',
#  'Lamb, Australian, imported, fresh, loin, separable lean and fat, trimmed to 1/8" fat, raw',
#  'POPEYES, Fried Chicken, Mild, Wing, meat only, skin and breading removed',
#  'Lamb, Australian, imported, fresh, leg, shank half, separable lean and fat, trimmed to 1/8" fat, raw',
#  'Succotash, (corn and limas), cooked, boiled, drained, with salt',
#  'Willow, young leaves, chopped (Alaska Native)',
#  'Soup, SWANSON, beef broth, lower sodium',
#  'Pasta, fresh-refrigerated, spinach, cooked',
#  'CRACKER BARREL, grilled sirloin steak',
#  'Seeds, lotus seeds, dried',
#  'Broccoli, stalks, raw',
#  'Cowpeas, young pods with seeds, cooked, boiled, drained, with salt',
#  'Alcoholic Beverage, wine, table, red, Carignane',
#  'Beverages, V8 SPLASH Juice Drinks, Berry Blend',
#  'Bear, black, meat (Alaska Native)',
#  'POPEYES, Fried Chicken, Mild, Drumstick, meat only, skin and breading removed',
#  'Alcoholic Beverage, wine, table, red, Lemberger',
#  'Squash, Indian, raw (Navajo)',
#  'Chicken, broilers or fryers, skin only, cooked, fried, batter',
#  'Nuts, coconut meat, dried (desiccated), creamed',
#  'Veal, shank (fore and hind), separable lean and fat, raw',
#  'Arrowhead, cooked, boiled, drained, without salt',
#  'Muffins, corn, prepared from recipe, made with low fat (2%) milk',
#  'Game meat, bison, shoulder clod, separable lean only, trimmed to 0" fat, raw',
#  'Alcoholic beverage, wine, table, white, Pinot Gris (Grigio)',
#  'Game meat, bison, ribeye, separable lean only, trimmed to 0" fat, raw',
#  'Mutton, cooked, roasted (Navajo)',
#  'Fish, pike, northern, liver (Alaska Native)',
#  'Seeds, sesame flour, low-fat',
#  'Fish, lingcod, meat, raw (Alaska Native)',
#  'Oheloberries, raw',
#  'Longans, dried',
#  'Sea lion, Steller, liver (Alaska Native)',
#  'Beverages, V8 SPLASH Juice Drinks, Diet Berry Blend',
#  'Sweeteners, for baking, contains sugar and sucralose',
#  'Alcoholic Beverage, wine, table, red, Gamay',
#  'Seeds, sisymbrium sp. seeds, whole, dried',
#  'Duck, young duckling, domesticated, White Pekin, leg, meat only, bone in, cooked without skin, braised',
#  'Sourdock, young leaves (Alaska Native)',
#  'Lamb, Australian, imported, fresh, shoulder, arm, separable lean and fat, trimmed to 1/8" fat, cooked, braised',
#  'Mothbeans, mature seeds, cooked, boiled, without salt',
#  'Pancakes, whole-wheat, dry mix, incomplete',
#  'Beverages, V8 SPLASH Juice Drinks, Orange Pineapple',
#  'Alcoholic Beverage, wine, table, red, Mouvedre',
#  'Beans, pinto, mature seeds, sprouted, raw',
#  'Nuts, chestnuts, european, boiled and steamed',
#  'Spaghetti, spinach, cooked',
#  'Oil, cooking and salad, ENOVA, 80% diglycerides',
#  'Cheese, white, queso blanco',
#  'Chicken, broilers or fryers, meat and skin and giblets and neck, cooked, fried, flour',
#  'Sweeteners, for baking, brown, contains sugar and sucralose',
#  'Borage, cooked, boiled, drained, with salt',
#  'Lamb, Australian, imported, fresh, composite of trimmed retail cuts, separable lean only, trimmed to 1/8" fat, raw']

# %%
# find food in nutrients by name
def find_food(nutrients, food_name):
    for food in nutrients:
        if food == food_name:
            return nutrients[food]
    return None

# find_food(nutrients, 'Oats, raw')
filter_food(nutrients, 'Strawberries')

# food_obj = nutrients['Apple, raw']
# # show only nutrients with values greater than 0
# for key, value in food_obj.items():
#     if value > 0:
#         print(key, value)
# Out:
# ["Strawberries, frozen, unsweetened (Includes foods for USDA's Food Distribution Program)"]

# %%
# read data from foundationDownload.json

with open('FoodData_Central_survey_food_json_2022-10-28.json') as f:
    foundation_data = json.load(f)
len(foundation_data['SRLegacyFoods'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[195], line 5
#       3 with open('FoodData_Central_survey_food_json_2022-10-28.json') as f:
#       4     foundation_data = json.load(f)
# ----> 5 len(foundation_data['SRLegacyFoods'])
#
# KeyError: 'SRLegacyFoods'
